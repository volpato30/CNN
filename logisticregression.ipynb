# %%
__docformat__ = 'restructedtext en'

import pickle
import gzip
import os
import sys
import timeit
from sklearn import datasets
import numpy

import theano
import theano.tensor as T


class LogisticRegression(object):
    """Multi-class Logistic Regression Class

    The logistic regression is fully described by a weight matrix :math:`W`
    and bias vector :math:`b`. Classification is done by projecting data
    points onto a set of hyperplanes, the distance to which is used to
    determine a class membership probability.
    """

    def __init__(self, input, n_in, n_out):
        """ Initialize the parameters of the logistic regression

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
                      architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
                     which the datapoints lie

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
                      which the labels lie

        """
        # start-snippet-1
        # initialize with 0 the weights W as a matrix of shape (n_in, n_out)
        self.W = theano.shared(
            value=numpy.zeros(
                (n_in, n_out),
                dtype=theano.config.floatX
            ),
            name='W',
            borrow=True
        )
        # initialize the biases b as a vector of n_out 0s
        self.b = theano.shared(
            value=numpy.zeros(
                (n_out,),
                dtype=theano.config.floatX
            ),
            name='b',
            borrow=True
        )

        # symbolic expression for computing the matrix of class-membership
        # probabilities
        # Where:
        # W is a matrix where column-k represent the separation hyperplane for
        # class-k
        # x is a matrix where row-j  represents input training sample-j
        # b is a vector where element-k represent the free parameter of
        # hyperplane-k
        self.p_y_given_x = T.nnet.softmax(T.dot(input, self.W) + self.b)

        # symbolic description of how to compute prediction as class whose
        # probability is maximal
        self.y_pred = T.argmax(self.p_y_given_x, axis=1)
        # end-snippet-1

        # parameters of the model
        self.params = [self.W, self.b]

        # keep track of model input
        self.input = input

    def negative_log_likelihood(self, y):
        """Return the mean of the negative log-likelihood of the prediction
        of this model under a given target distribution.

        .. math::

            \frac{1}{|\mathcal{D}|} \mathcal{L} (\theta=\{W,b\}, \mathcal{D}) =
            \frac{1}{|\mathcal{D}|} \sum_{i=0}^{|\mathcal{D}|}
                \log(P(Y=y^{(i)}|x^{(i)}, W,b)) \\
            \ell (\theta=\{W,b\}, \mathcal{D})

        :type y: theano.tensor.TensorType
        :param y: corresponds to a vector that gives for each example the
                  correct label

        Note: we use the mean instead of the sum so that
              the learning rate is less dependent on the batch size
        """
        # y.shape[0] is (symbolically) the number of rows in y, i.e.,
        # number of examples (call it n) in the minibatch
        # T.arange(y.shape[0]) is a symbolic vector which will contain
        # [0,1,2,... n-1] T.log(self.p_y_given_x) is a matrix of
        # Log-Probabilities (call it LP) with one row per example and
        # one column per class LP[T.arange(y.shape[0]),y] is a vector
        # v containing [LP[0,y[0]], LP[1,y[1]], LP[2,y[2]], ...,
        # LP[n-1,y[n-1]]] and T.mean(LP[T.arange(y.shape[0]),y]) is
        # the mean (across minibatch examples) of the elements in v,
        # i.e., the mean log-likelihood across the minibatch.
        return -T.mean(T.log(self.p_y_given_x)[T.arange(y.shape[0]), y])

    def errors(self, y):
        """Return a float representing the number of errors in the minibatch
        over the total number of examples of the minibatch ; zero one
        loss over the size of the minibatch

        :type y: theano.tensor.TensorType
        :param y: corresponds to a vector that gives for each example the
                  correct label
        """

        # check if y has same dimension of y_pred
        if y.ndim != self.y_pred.ndim:
            raise TypeError(
                'y should have the same shape as self.y_pred',
                ('y', y.type, 'y_pred', self.y_pred.type)
            )
        # check if y is of the correct datatype
        if y.dtype.startswith('int'):
            # the T.neq operator returns a vector of 0s and 1s, where 1
            # represents a mistake in prediction
            return T.mean(T.neq(self.y_pred, y))
        else:
            raise NotImplementedError()


def load_data():
    
    face=datasets.fetch_olivetti_faces(shuffle=True)
    train_set=(face.data[0:200,],face.target[0:200,])
    valid_set=(face.data[200:300,],face.target[200:300,])
    test_set =(face.data[300:400,],face.target[300:400,])
    #train_set, valid_set, test_set format: tuple(input, target)
    #input is an numpy.ndarray of 2 dimensions (a matrix)
    #witch row's correspond to an example. target is a
    #numpy.ndarray of 1 dimensions (vector)) that have the same length as
    #the number of rows in the input. It should give the target
    #target to the example with the same index in the input.

    def shared_dataset(data_xy, borrow=True):
        """ Function that loads the dataset into shared variables

        The reason we store our dataset in shared variables is to allow
        Theano to copy it into the GPU memory (when code is run on GPU).
        Since copying data into the GPU is slow, copying a minibatch everytime
        is needed (the default behaviour if the data is not in a shared
        variable) would lead to a large decrease in performance.
        """
        data_x, data_y = data_xy
        shared_x = theano.shared(numpy.asarray(data_x,
                                               dtype=theano.config.floatX),
                                 borrow=borrow)
        shared_y = theano.shared(numpy.asarray(data_y,
                                               dtype=theano.config.floatX),
                                 borrow=borrow)
        # When storing data on the GPU it has to be stored as floats
        # therefore we will store the labels as ``floatX`` as well
        # (``shared_y`` does exactly that). But during our computations
        # we need them as ints (we use labels as index, and if they are
        # floats it doesn't make sense) therefore instead of returning
        # ``shared_y`` we will have to cast it to int. This little hack
        # lets ous get around this issue
        return shared_x, T.cast(shared_y, 'int32')

    test_set_x, test_set_y = shared_dataset(test_set)
    valid_set_x, valid_set_y = shared_dataset(valid_set)
    train_set_x, train_set_y = shared_dataset(train_set)

    rval = [(train_set_x, train_set_y), (valid_set_x, valid_set_y),
            (test_set_x, test_set_y)]
    return rval


def sgd_optimization_mnist(learning_rate=0.13, n_epochs=100,
                           batch_size=20):
    
    datasets = load_data()

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = int(train_set_x.get_value(borrow=True).shape[0] / batch_size)
    print(n_train_batches)
    n_valid_batches = int(valid_set_x.get_value(borrow=True).shape[0] / batch_size)
    n_test_batches = int(test_set_x.get_value(borrow=True).shape[0] / batch_size)

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print('... building the model')

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch

    # generate symbolic variables for input (x and y represent a
    # minibatch)
    x = T.matrix('x')  # data, presented as rasterized images
    y = T.ivector('y')  # labels, presented as 1D vector of [int] labels
    classifier = LogisticRegression(input=x, n_in=4096, n_out=40)

    cost = classifier.negative_log_likelihood(y)

    test_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: test_set_x[index * batch_size: (index + 1) * batch_size],
            y: test_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: valid_set_x[index * batch_size: (index + 1) * batch_size],
            y: valid_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    # compute the gradient of cost with respect to theta = (W,b)
    g_W = T.grad(cost=cost, wrt=classifier.W)
    g_b = T.grad(cost=cost, wrt=classifier.b)

    updates = [(classifier.W, classifier.W - learning_rate * g_W),
               (classifier.b, classifier.b - learning_rate * g_b)]

    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )


    ###############
    # TRAIN MODEL #
    ###############
    print('... training the model')
    # early-stopping parameters
    patience = 400  # look as this many examples regardless
    patience_increase = 2  # wait this much longer when a new best is
                                  # found
    improvement_threshold = 0.995  # a relative improvement of this much is
                                  # considered significant
    validation_frequency = min(n_train_batches, patience / 2)
                                  # go through this many
                                  # minibatche before checking the network
                                  # on the validation set; in this case we
                                  # check every epoch

    best_validation_loss = numpy.inf
    test_score = 0.
    start_time = timeit.default_timer()

    done_looping = False
    epoch = 0
    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):

            minibatch_avg_cost = train_model(minibatch_index)
            # iteration number
            iter = (epoch - 1) * n_train_batches + minibatch_index

            if (iter + 1) % validation_frequency == 0:
                # compute zero-one loss on validation set
                validation_losses = [validate_model(i)
                                     for i in range(n_valid_batches)]
                this_validation_loss = numpy.mean(validation_losses)

                print((
                    'epoch %i, minibatch %i/%i, validation error %f %%' %
                    (
                        epoch,
                        minibatch_index + 1,
                        n_train_batches,
                        this_validation_loss * 100.
                    )
                ))

                # if we got the best validation score until now
                if this_validation_loss < best_validation_loss:
                    #improve patience if loss improvement is good enough
                    if this_validation_loss < best_validation_loss *  \
                       improvement_threshold:
                        patience = max(patience, iter * patience_increase)

                    best_validation_loss = this_validation_loss
                    # test it on the test set

                    test_losses = [test_model(i)
                                   for i in range(n_test_batches)]
                    test_score = numpy.mean(test_losses)

                    print((
                        (
                            '     epoch %i, minibatch %i/%i, test error of'
                            ' best model %f %%'
                        ) %
                        (
                            epoch,
                            minibatch_index + 1,
                            n_train_batches,
                            test_score * 100.
                        )
                    ))

                    
                    with open('workfile.pkl', 'wb') as f:
                        pickle.dump(classifier, f)

                  
            if patience <= iter:
                done_looping = True
                break

    end_time = timeit.default_timer()
    print((
        (
            'Optimization complete with best validation score of %f %%,'
            'with test performance %f %%'
        )
        % (best_validation_loss * 100., test_score * 100.)
    ))
    print('The code run for %d epochs, with %f epochs/sec' % (
        epoch, 1. * epoch / (end_time - start_time)))
    print(('The code for file '  +
                          ' ran for %.1fs' % ((end_time - start_time))), file=sys.stderr)

# %%
sgd_optimization_mnist()
# Out:
# 10
# ... building the model
# ... training the model
# epoch 1, minibatch 10/10, validation error 97.000000 %
#      epoch 1, minibatch 10/10, test error of best model 99.000000 %
# epoch 2, minibatch 10/10, validation error 97.000000 %
# epoch 3, minibatch 10/10, validation error 97.000000 %
#      epoch 3, minibatch 10/10, test error of best model 95.000000 %
# epoch 4, minibatch 10/10, validation error 98.000000 %
# epoch 5, minibatch 10/10, validation error 95.000000 %
#      epoch 5, minibatch 10/10, test error of best model 97.000000 %
# epoch 6, minibatch 10/10, validation error 94.000000 %
#      epoch 6, minibatch 10/10, test error of best model 92.000000 %
# epoch 7, minibatch 10/10, validation error 86.000000 %
#      epoch 7, minibatch 10/10, test error of best model 93.000000 %
# epoch 8, minibatch 10/10, validation error 89.000000 %
# epoch 9, minibatch 10/10, validation error 89.000000 %
# epoch 10, minibatch 10/10, validation error 94.000000 %
# epoch 11, minibatch 10/10, validation error 88.000000 %
# epoch 12, minibatch 10/10, validation error 81.000000 %
#      epoch 12, minibatch 10/10, test error of best model 78.000000 %
# epoch 13, minibatch 10/10, validation error 97.000000 %
# epoch 14, minibatch 10/10, validation error 66.000000 %
#      epoch 14, minibatch 10/10, test error of best model 72.000000 %
# epoch 15, minibatch 10/10, validation error 55.000000 %
#      epoch 15, minibatch 10/10, test error of best model 57.000000 %
# epoch 16, minibatch 10/10, validation error 95.000000 %
# epoch 17, minibatch 10/10, validation error 90.000000 %
# epoch 18, minibatch 10/10, validation error 57.000000 %
# epoch 19, minibatch 10/10, validation error 63.000000 %
# epoch 20, minibatch 10/10, validation error 74.000000 %
# epoch 21, minibatch 10/10, validation error 49.000000 %
#      epoch 21, minibatch 10/10, test error of best model 61.000000 %
# epoch 22, minibatch 10/10, validation error 83.000000 %
# epoch 23, minibatch 10/10, validation error 48.000000 %
#      epoch 23, minibatch 10/10, test error of best model 43.000000 %
# epoch 24, minibatch 10/10, validation error 94.000000 %
# epoch 25, minibatch 10/10, validation error 62.000000 %
# epoch 26, minibatch 10/10, validation error 37.000000 %
#      epoch 26, minibatch 10/10, test error of best model 37.000000 %
# epoch 27, minibatch 10/10, validation error 29.000000 %
#      epoch 27, minibatch 10/10, test error of best model 36.000000 %
# epoch 28, minibatch 10/10, validation error 44.000000 %
# epoch 29, minibatch 10/10, validation error 67.000000 %
# epoch 30, minibatch 10/10, validation error 88.000000 %
# epoch 31, minibatch 10/10, validation error 41.000000 %
# epoch 32, minibatch 10/10, validation error 44.000000 %
# epoch 33, minibatch 10/10, validation error 50.000000 %
# epoch 34, minibatch 10/10, validation error 61.000000 %
# epoch 35, minibatch 10/10, validation error 34.000000 %
# epoch 36, minibatch 10/10, validation error 25.000000 %
#      epoch 36, minibatch 10/10, test error of best model 31.000000 %
# epoch 37, minibatch 10/10, validation error 39.000000 %
# epoch 38, minibatch 10/10, validation error 56.000000 %
# epoch 39, minibatch 10/10, validation error 37.000000 %
# epoch 40, minibatch 10/10, validation error 24.000000 %
#      epoch 40, minibatch 10/10, test error of best model 28.000000 %
# epoch 41, minibatch 10/10, validation error 28.000000 %
# epoch 42, minibatch 10/10, validation error 22.000000 %
#      epoch 42, minibatch 10/10, test error of best model 26.000000 %
# epoch 43, minibatch 10/10, validation error 26.000000 %
# epoch 44, minibatch 10/10, validation error 26.000000 %
# epoch 45, minibatch 10/10, validation error 30.000000 %
# epoch 46, minibatch 10/10, validation error 28.000000 %
# epoch 47, minibatch 10/10, validation error 24.000000 %
# epoch 48, minibatch 10/10, validation error 19.000000 %
#      epoch 48, minibatch 10/10, test error of best model 21.000000 %
# epoch 49, minibatch 10/10, validation error 20.000000 %
# epoch 50, minibatch 10/10, validation error 18.000000 %
#      epoch 50, minibatch 10/10, test error of best model 18.000000 %
# epoch 51, minibatch 10/10, validation error 42.000000 %
# epoch 52, minibatch 10/10, validation error 24.000000 %
# epoch 53, minibatch 10/10, validation error 23.000000 %
# epoch 54, minibatch 10/10, validation error 17.000000 %
#      epoch 54, minibatch 10/10, test error of best model 16.000000 %
# epoch 55, minibatch 10/10, validation error 14.000000 %
#      epoch 55, minibatch 10/10, test error of best model 12.000000 %
# epoch 56, minibatch 10/10, validation error 12.000000 %
#      epoch 56, minibatch 10/10, test error of best model 10.000000 %
# epoch 57, minibatch 10/10, validation error 12.000000 %
# epoch 58, minibatch 10/10, validation error 12.000000 %
# epoch 59, minibatch 10/10, validation error 12.000000 %
# epoch 60, minibatch 10/10, validation error 12.000000 %
# epoch 61, minibatch 10/10, validation error 12.000000 %
# epoch 62, minibatch 10/10, validation error 12.000000 %
# epoch 63, minibatch 10/10, validation error 11.000000 %
#      epoch 63, minibatch 10/10, test error of best model 11.000000 %
# epoch 64, minibatch 10/10, validation error 11.000000 %
# epoch 65, minibatch 10/10, validation error 11.000000 %
# epoch 66, minibatch 10/10, validation error 11.000000 %
# epoch 67, minibatch 10/10, validation error 11.000000 %
# epoch 68, minibatch 10/10, validation error 12.000000 %
# epoch 69, minibatch 10/10, validation error 12.000000 %
# epoch 70, minibatch 10/10, validation error 13.000000 %
# epoch 71, minibatch 10/10, validation error 13.000000 %
# epoch 72, minibatch 10/10, validation error 13.000000 %
# epoch 73, minibatch 10/10, validation error 13.000000 %
# epoch 74, minibatch 10/10, validation error 13.000000 %
# epoch 75, minibatch 10/10, validation error 13.000000 %
# epoch 76, minibatch 10/10, validation error 13.000000 %
# epoch 77, minibatch 10/10, validation error 13.000000 %
# epoch 78, minibatch 10/10, validation error 13.000000 %
# epoch 79, minibatch 10/10, validation error 13.000000 %
# epoch 80, minibatch 10/10, validation error 13.000000 %
# epoch 81, minibatch 10/10, validation error 13.000000 %
# epoch 82, minibatch 10/10, validation error 13.000000 %
# epoch 83, minibatch 10/10, validation error 13.000000 %
# epoch 84, minibatch 10/10, validation error 13.000000 %
# epoch 85, minibatch 10/10, validation error 13.000000 %
# epoch 86, minibatch 10/10, validation error 13.000000 %
# epoch 87, minibatch 10/10, validation error 13.000000 %
# epoch 88, minibatch 10/10, validation error 13.000000 %
# epoch 89, minibatch 10/10, validation error 13.000000 %
# epoch 90, minibatch 10/10, validation error 13.000000 %
# epoch 91, minibatch 10/10, validation error 13.000000 %
# epoch 92, minibatch 10/10, validation error 13.000000 %
# epoch 93, minibatch 10/10, validation error 13.000000 %
# epoch 94, minibatch 10/10, validation error 13.000000 %
# epoch 95, minibatch 10/10, validation error 13.000000 %
# epoch 96, minibatch 10/10, validation error 13.000000 %
# epoch 97, minibatch 10/10, validation error 13.000000 %
# epoch 98, minibatch 10/10, validation error 13.000000 %
# epoch 99, minibatch 10/10, validation error 13.000000 %
# epoch 100, minibatch 10/10, validation error 13.000000 %
# Optimization complete with best validation score of 11.000000 %,with test performance 11.000000 %
# The code run for 100 epochs, with 120.244544 epochs/sec
# The code for file  ran for 0.8s

# %%
def predict():
    """
    An example of how to load a trained model and use it
    to predict labels.
    """

    # load the saved model
    classifier = pickle.load(open('workfile.pkl','rb'))

    # compile a predictor function
    predict_model = theano.function(
        inputs=[classifier.input],
        outputs=classifier.y_pred)

    # We can test it on some examples from test test
    face=datasets.fetch_olivetti_faces(shuffle=True)
    predicted_values = predict_model(face.data[300:400,])
    print ("Predicted values for the first 10 examples in test set:")
    print(predicted_values)

# %%
predict()
# Out:
# Predicted values for the first 10 examples in test set:
# [20 33 39 38 17 22  9 36  9 35 16  6 30  4 20 27 22 14 14 18 13 35  4 26 32
#  20  8 12 34 36  9  8 26 11 29  5 32 25 35 21 10 36 27 35  3  5 34 30 29  2
#  18 16 15 24 20  3  3 12 18 37 28 36 14 28 37 17 15 33 33 19 24 11 26  7 33
#  25 16 33 38 17 38 14 19 31  8  7  8 29 24 27 21  0 35 19 22 32 19 25  4 39]

# %% [markdown]
# ```python
# print "Hello World"
# ```

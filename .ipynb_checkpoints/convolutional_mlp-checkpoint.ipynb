# %%
import os
import sys
import timeit
import pickle
import numpy
import theano
import theano.tensor as T
from theano.tensor.signal import downsample
from theano.tensor.nnet import conv

from logistic_sgd import LogisticRegression, load_data
from mlp import HiddenLayer


class LeNetConvPoolLayer(object):
    """Pool Layer of a convolutional network """

    def __init__(self, rng, input, filter_shape, image_shape, poolsize=(2, 2)):
        """
        Allocate a LeNetConvPoolLayer with shared variable internal parameters.

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dtensor4
        :param input: symbolic image tensor, of shape image_shape

        :type filter_shape: tuple or list of length 4
        :param filter_shape: (number of filters, num input feature maps,
                              filter height, filter width)

        :type image_shape: tuple or list of length 4
        :param image_shape: (batch size, num input feature maps,
                             image height, image width)

        :type poolsize: tuple or list of length 2
        :param poolsize: the downsampling (pooling) factor (#rows, #cols)
        """

        assert image_shape[1] == filter_shape[1]
        self.input = input

        # there are "num input feature maps * filter height * filter width"
        # inputs to each hidden unit
        fan_in = numpy.prod(filter_shape[1:])
        # each unit in the lower layer receives a gradient from:
        # "num output feature maps * filter height * filter width" /
        #   pooling size
        fan_out = (filter_shape[0] * numpy.prod(filter_shape[2:]) /
                   numpy.prod(poolsize))
        # initialize weights with random weights
        W_bound = numpy.sqrt(6. / (fan_in + fan_out))
        self.W = theano.shared(
            numpy.asarray(
                rng.uniform(low=-W_bound, high=W_bound, size=filter_shape),
                dtype=theano.config.floatX
            ),
            borrow=True
        )

        # the bias is a 1D tensor -- one bias per output feature map
        b_values = numpy.zeros((filter_shape[0],), dtype=theano.config.floatX)
        self.b = theano.shared(value=b_values, borrow=True)

        # convolve input feature maps with filters
        conv_out = conv.conv2d(
            input=input,
            filters=self.W,
            filter_shape=filter_shape,
            image_shape=image_shape
        )

        # downsample each feature map individually, using maxpooling
        pooled_out = downsample.max_pool_2d(
            input=conv_out,
            ds=poolsize,
            ignore_border=True
        )

        # add the bias term. Since the bias is a vector (1D array), we first
        # reshape it to a tensor of shape (1, n_filters, 1, 1). Each bias will
        # thus be broadcasted across mini-batches and feature map
        # width & height
        self.output = T.tanh(pooled_out + self.b.dimshuffle('x', 0, 'x', 'x'))

        # store parameters of this layer
        self.params = [self.W, self.b]

        # keep track of model input
        self.input = input

# %%
def evaluate_lenet5(learning_rate=0.1, n_epochs=200,
                    nkerns=[20, 50], batch_size=20):
    """ 
    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
                          gradient)

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: path to the dataset used for training /testing (MNIST here)

    :type nkerns: list of ints
    :param nkerns: number of kernels on each layer
    """

    rng = numpy.random.RandomState(23455)

    datasets = load_data()

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = int(train_set_x.get_value(borrow=True).shape[0] / batch_size)
    n_valid_batches = int(valid_set_x.get_value(borrow=True).shape[0] / batch_size)
    n_test_batches = int(test_set_x.get_value(borrow=True).shape[0] / batch_size)


    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch

    # start-snippet-1
    x = T.matrix('x')   # the data is presented as rasterized images
    y = T.ivector('y')  # the labels are presented as 1D vector of
                        # [int] labels

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print('... building the model')

    layer0_input = x.reshape((batch_size, 1, 64, 64))

    
    layer0 = LeNetConvPoolLayer(
        rng,
        input=layer0_input,
        image_shape=(batch_size, 1, 64, 64),
        filter_shape=(nkerns[0], 1, 5, 5),
        poolsize=(2, 2)
    )

    layer1 = LeNetConvPoolLayer(
        rng,
        input=layer0.output,
        image_shape=(batch_size, nkerns[0], 30, 30),
        filter_shape=(nkerns[1], nkerns[0], 5, 5),
        poolsize=(2, 2)
    )

    layer2_input = layer1.output.flatten(2)

    # construct a fully-connected sigmoidal layer
    layer2 = HiddenLayer(
        rng,
        input=layer2_input,
        n_in=nkerns[1] * 13 * 13,
        n_out=500,
        activation=T.tanh
    )

    # classify the values of the fully-connected sigmoidal layer
    layer3 = LogisticRegression(input=layer2.output, n_in=500, n_out=40)

    # the cost we minimize during training is the NLL of the model
    cost = layer3.negative_log_likelihood(y)

    # create a function to compute the mistakes that are made by the model
    test_model = theano.function(
        [index],
        layer3.errors(y),
        givens={
            x: test_set_x[index * batch_size: (index + 1) * batch_size],
            y: test_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        [index],
        layer3.errors(y),
        givens={
            x: valid_set_x[index * batch_size: (index + 1) * batch_size],
            y: valid_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    # create a list of all model parameters to be fit by gradient descent
    params = layer3.params + layer2.params + layer1.params + layer0.params

    # create a list of gradients for all model parameters
    grads = T.grad(cost, params)

    # train_model is a function that updates the model parameters by
    # SGD Since this model has many parameters, it would be tedious to
    # manually create an update rule for each model parameter. We thus
    # create the updates list by automatically looping over all
    # (params[i], grads[i]) pairs.
    updates = [
        (param_i, param_i - learning_rate * grad_i)
        for param_i, grad_i in zip(params, grads)
    ]

    train_model = theano.function(
        [index],
        cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )
    # end-snippet-1

    ###############
    # TRAIN MODEL #
    ###############
    print('... training')
    # early-stopping parameters
    patience = 2000  # look as this many examples regardless
    patience_increase = 2  # wait this much longer when a new best is
                           # found
    improvement_threshold = 0.995  # a relative improvement of this much is
                                   # considered significant
    validation_frequency = min(n_train_batches, patience / 2)
                                  # go through this many
                                  # minibatche before checking the network
                                  # on the validation set; in this case we
                                  # check every epoch

    best_validation_loss = numpy.inf
    best_iter = 0
    test_score = 0.
    start_time = timeit.default_timer()

    epoch = 0
    done_looping = False

    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):

            iter = (epoch - 1) * n_train_batches + minibatch_index
            if iter % 500 == 0:
                learning_rate*=0.8
            
            if iter % 100 == 0:
                print('training @ iter = ', iter)
            cost_ij = train_model(minibatch_index)

            if (iter + 1) % validation_frequency == 0:

                # compute zero-one loss on validation set
                validation_losses = [validate_model(i) for i
                                     in range(n_valid_batches)]
                this_validation_loss = numpy.mean(validation_losses)
                print(('epoch %i, minibatch %i/%i, validation error %f %%' %
                      (epoch, minibatch_index + 1, n_train_batches,
                       this_validation_loss * 100.)))

                # if we got the best validation score until now
                if this_validation_loss < best_validation_loss:

                    #improve patience if loss improvement is good enough
                    if this_validation_loss < best_validation_loss *  \
                       improvement_threshold:
                        patience = max(patience, iter * patience_increase)

                    # save best validation score and iteration number
                    best_validation_loss = this_validation_loss
                    best_iter = iter

                    # test it on the test set
                    test_losses = [
                        test_model(i)
                        for i in range(n_test_batches)
                    ]
                    test_score = numpy.mean(test_losses)
                    print((('     epoch %i, minibatch %i/%i, test error of '
                           'best model %f %%') %
                          (epoch, minibatch_index + 1, n_train_batches,
                           test_score * 100.)))
                    with open('weight.pkl', 'wb') as f:
                        pickle.dump([layer0,layer1,layer2,layer3], f)

            if patience <= iter:
                done_looping = True
                break

    end_time = timeit.default_timer()
    print('Optimization complete.')
    print(('Best validation score of %f %% obtained at iteration %i, '
          'with test performance %f %%' %
          (best_validation_loss * 100., best_iter + 1, test_score * 100.)))
    print(('The code for file ran for %.2fm' % ((end_time - start_time) / 60.)), file=sys.stderr)

# %%
evaluate_lenet5(nkerns=[30, 50],n_epochs=200)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 10/10, validation error 91.000000 %
#      epoch 1, minibatch 10/10, test error of best model 97.000000 %
# epoch 2, minibatch 10/10, validation error 95.000000 %
# epoch 3, minibatch 10/10, validation error 93.000000 %
# epoch 4, minibatch 10/10, validation error 88.000000 %
#      epoch 4, minibatch 10/10, test error of best model 97.000000 %
# epoch 5, minibatch 10/10, validation error 92.000000 %
# epoch 6, minibatch 10/10, validation error 88.000000 %
# epoch 7, minibatch 10/10, validation error 74.000000 %
#      epoch 7, minibatch 10/10, test error of best model 77.000000 %
# epoch 8, minibatch 10/10, validation error 58.000000 %
#      epoch 8, minibatch 10/10, test error of best model 65.000000 %
# epoch 9, minibatch 10/10, validation error 64.000000 %
# epoch 10, minibatch 10/10, validation error 51.000000 %
#      epoch 10, minibatch 10/10, test error of best model 47.000000 %
# training @ iter =  100
# epoch 11, minibatch 10/10, validation error 35.000000 %
#      epoch 11, minibatch 10/10, test error of best model 43.000000 %
# epoch 12, minibatch 10/10, validation error 27.000000 %
#      epoch 12, minibatch 10/10, test error of best model 31.000000 %
# epoch 13, minibatch 10/10, validation error 21.000000 %
#      epoch 13, minibatch 10/10, test error of best model 26.000000 %
# epoch 14, minibatch 10/10, validation error 17.000000 %
#      epoch 14, minibatch 10/10, test error of best model 15.000000 %
# epoch 15, minibatch 10/10, validation error 11.000000 %
#      epoch 15, minibatch 10/10, test error of best model 10.000000 %
# epoch 16, minibatch 10/10, validation error 9.000000 %
#      epoch 16, minibatch 10/10, test error of best model 8.000000 %
# epoch 17, minibatch 10/10, validation error 8.000000 %
#      epoch 17, minibatch 10/10, test error of best model 8.000000 %
# epoch 18, minibatch 10/10, validation error 8.000000 %
# epoch 19, minibatch 10/10, validation error 8.000000 %
# epoch 20, minibatch 10/10, validation error 8.000000 %
# training @ iter =  200
# epoch 21, minibatch 10/10, validation error 7.000000 %
#      epoch 21, minibatch 10/10, test error of best model 8.000000 %
# epoch 22, minibatch 10/10, validation error 7.000000 %
# epoch 23, minibatch 10/10, validation error 7.000000 %
# epoch 24, minibatch 10/10, validation error 8.000000 %
# epoch 25, minibatch 10/10, validation error 8.000000 %
# epoch 26, minibatch 10/10, validation error 8.000000 %
# epoch 27, minibatch 10/10, validation error 9.000000 %
# epoch 28, minibatch 10/10, validation error 9.000000 %
# epoch 29, minibatch 10/10, validation error 9.000000 %
# epoch 30, minibatch 10/10, validation error 9.000000 %
# training @ iter =  300
# epoch 31, minibatch 10/10, validation error 9.000000 %
# epoch 32, minibatch 10/10, validation error 9.000000 %
# epoch 33, minibatch 10/10, validation error 9.000000 %
# epoch 34, minibatch 10/10, validation error 9.000000 %
# epoch 35, minibatch 10/10, validation error 9.000000 %
# epoch 36, minibatch 10/10, validation error 9.000000 %
# epoch 37, minibatch 10/10, validation error 9.000000 %
# epoch 38, minibatch 10/10, validation error 9.000000 %
# epoch 39, minibatch 10/10, validation error 9.000000 %
# epoch 40, minibatch 10/10, validation error 9.000000 %
# training @ iter =  400
# epoch 41, minibatch 10/10, validation error 9.000000 %
# epoch 42, minibatch 10/10, validation error 9.000000 %
# epoch 43, minibatch 10/10, validation error 9.000000 %
# epoch 44, minibatch 10/10, validation error 9.000000 %
# epoch 45, minibatch 10/10, validation error 9.000000 %
# epoch 46, minibatch 10/10, validation error 9.000000 %
# epoch 47, minibatch 10/10, validation error 9.000000 %
# epoch 48, minibatch 10/10, validation error 9.000000 %
# epoch 49, minibatch 10/10, validation error 9.000000 %
# epoch 50, minibatch 10/10, validation error 9.000000 %
# training @ iter =  500
# epoch 51, minibatch 10/10, validation error 9.000000 %
# epoch 52, minibatch 10/10, validation error 9.000000 %
# epoch 53, minibatch 10/10, validation error 9.000000 %
# epoch 54, minibatch 10/10, validation error 9.000000 %
# epoch 55, minibatch 10/10, validation error 9.000000 %
# epoch 56, minibatch 10/10, validation error 9.000000 %
# epoch 57, minibatch 10/10, validation error 9.000000 %
# epoch 58, minibatch 10/10, validation error 9.000000 %
# epoch 59, minibatch 10/10, validation error 9.000000 %
# epoch 60, minibatch 10/10, validation error 9.000000 %
# training @ iter =  600
# epoch 61, minibatch 10/10, validation error 9.000000 %
# epoch 62, minibatch 10/10, validation error 9.000000 %
# epoch 63, minibatch 10/10, validation error 9.000000 %
# epoch 64, minibatch 10/10, validation error 9.000000 %
# epoch 65, minibatch 10/10, validation error 9.000000 %
# epoch 66, minibatch 10/10, validation error 9.000000 %
# epoch 67, minibatch 10/10, validation error 9.000000 %
# epoch 68, minibatch 10/10, validation error 9.000000 %
# epoch 69, minibatch 10/10, validation error 9.000000 %
# epoch 70, minibatch 10/10, validation error 9.000000 %
# training @ iter =  700
# epoch 71, minibatch 10/10, validation error 9.000000 %
# epoch 72, minibatch 10/10, validation error 9.000000 %
# epoch 73, minibatch 10/10, validation error 9.000000 %
# epoch 74, minibatch 10/10, validation error 9.000000 %
# epoch 75, minibatch 10/10, validation error 9.000000 %
# epoch 76, minibatch 10/10, validation error 9.000000 %
# epoch 77, minibatch 10/10, validation error 9.000000 %
# epoch 78, minibatch 10/10, validation error 9.000000 %
# epoch 79, minibatch 10/10, validation error 9.000000 %
# epoch 80, minibatch 10/10, validation error 9.000000 %
# training @ iter =  800
# epoch 81, minibatch 10/10, validation error 9.000000 %
# epoch 82, minibatch 10/10, validation error 9.000000 %
# epoch 83, minibatch 10/10, validation error 9.000000 %
# epoch 84, minibatch 10/10, validation error 9.000000 %
# epoch 85, minibatch 10/10, validation error 9.000000 %
# epoch 86, minibatch 10/10, validation error 9.000000 %
# epoch 87, minibatch 10/10, validation error 9.000000 %
# epoch 88, minibatch 10/10, validation error 9.000000 %
# epoch 89, minibatch 10/10, validation error 9.000000 %
# epoch 90, minibatch 10/10, validation error 9.000000 %
# training @ iter =  900
# epoch 91, minibatch 10/10, validation error 9.000000 %
# epoch 92, minibatch 10/10, validation error 9.000000 %
# epoch 93, minibatch 10/10, validation error 9.000000 %
# epoch 94, minibatch 10/10, validation error 9.000000 %
# epoch 95, minibatch 10/10, validation error 9.000000 %
# epoch 96, minibatch 10/10, validation error 9.000000 %
# epoch 97, minibatch 10/10, validation error 9.000000 %
# epoch 98, minibatch 10/10, validation error 9.000000 %
# epoch 99, minibatch 10/10, validation error 9.000000 %
# epoch 100, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1000
# epoch 101, minibatch 10/10, validation error 9.000000 %
# epoch 102, minibatch 10/10, validation error 9.000000 %
# epoch 103, minibatch 10/10, validation error 9.000000 %
# epoch 104, minibatch 10/10, validation error 9.000000 %
# epoch 105, minibatch 10/10, validation error 9.000000 %
# epoch 106, minibatch 10/10, validation error 9.000000 %
# epoch 107, minibatch 10/10, validation error 9.000000 %
# epoch 108, minibatch 10/10, validation error 9.000000 %
# epoch 109, minibatch 10/10, validation error 9.000000 %
# epoch 110, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1100
# epoch 111, minibatch 10/10, validation error 9.000000 %
# epoch 112, minibatch 10/10, validation error 9.000000 %
# epoch 113, minibatch 10/10, validation error 9.000000 %
# epoch 114, minibatch 10/10, validation error 9.000000 %
# epoch 115, minibatch 10/10, validation error 9.000000 %
# epoch 116, minibatch 10/10, validation error 9.000000 %
# epoch 117, minibatch 10/10, validation error 9.000000 %
# epoch 118, minibatch 10/10, validation error 9.000000 %
# epoch 119, minibatch 10/10, validation error 9.000000 %
# epoch 120, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1200
# epoch 121, minibatch 10/10, validation error 9.000000 %
# epoch 122, minibatch 10/10, validation error 9.000000 %
# epoch 123, minibatch 10/10, validation error 9.000000 %
# epoch 124, minibatch 10/10, validation error 9.000000 %
# epoch 125, minibatch 10/10, validation error 9.000000 %
# epoch 126, minibatch 10/10, validation error 9.000000 %
# epoch 127, minibatch 10/10, validation error 9.000000 %
# epoch 128, minibatch 10/10, validation error 9.000000 %
# epoch 129, minibatch 10/10, validation error 9.000000 %
# epoch 130, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1300
# epoch 131, minibatch 10/10, validation error 9.000000 %
# epoch 132, minibatch 10/10, validation error 9.000000 %
# epoch 133, minibatch 10/10, validation error 9.000000 %
# epoch 134, minibatch 10/10, validation error 9.000000 %
# epoch 135, minibatch 10/10, validation error 9.000000 %
# epoch 136, minibatch 10/10, validation error 9.000000 %
# epoch 137, minibatch 10/10, validation error 9.000000 %
# epoch 138, minibatch 10/10, validation error 9.000000 %
# epoch 139, minibatch 10/10, validation error 9.000000 %
# epoch 140, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1400
# epoch 141, minibatch 10/10, validation error 9.000000 %
# epoch 142, minibatch 10/10, validation error 9.000000 %
# epoch 143, minibatch 10/10, validation error 9.000000 %
# epoch 144, minibatch 10/10, validation error 9.000000 %
# epoch 145, minibatch 10/10, validation error 9.000000 %
# epoch 146, minibatch 10/10, validation error 9.000000 %
# epoch 147, minibatch 10/10, validation error 9.000000 %
# epoch 148, minibatch 10/10, validation error 9.000000 %
# epoch 149, minibatch 10/10, validation error 9.000000 %
# epoch 150, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1500
# epoch 151, minibatch 10/10, validation error 9.000000 %
# epoch 152, minibatch 10/10, validation error 9.000000 %
# epoch 153, minibatch 10/10, validation error 9.000000 %
# epoch 154, minibatch 10/10, validation error 9.000000 %
# epoch 155, minibatch 10/10, validation error 9.000000 %
# epoch 156, minibatch 10/10, validation error 9.000000 %
# epoch 157, minibatch 10/10, validation error 9.000000 %
# epoch 158, minibatch 10/10, validation error 9.000000 %
# epoch 159, minibatch 10/10, validation error 9.000000 %
# epoch 160, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1600
# epoch 161, minibatch 10/10, validation error 9.000000 %
# epoch 162, minibatch 10/10, validation error 9.000000 %
# epoch 163, minibatch 10/10, validation error 9.000000 %
# epoch 164, minibatch 10/10, validation error 9.000000 %
# epoch 165, minibatch 10/10, validation error 9.000000 %
# epoch 166, minibatch 10/10, validation error 9.000000 %
# epoch 167, minibatch 10/10, validation error 9.000000 %
# epoch 168, minibatch 10/10, validation error 9.000000 %
# epoch 169, minibatch 10/10, validation error 9.000000 %
# epoch 170, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1700
# epoch 171, minibatch 10/10, validation error 9.000000 %
# epoch 172, minibatch 10/10, validation error 9.000000 %
# epoch 173, minibatch 10/10, validation error 9.000000 %
# epoch 174, minibatch 10/10, validation error 9.000000 %
# epoch 175, minibatch 10/10, validation error 9.000000 %
# epoch 176, minibatch 10/10, validation error 9.000000 %
# epoch 177, minibatch 10/10, validation error 9.000000 %
# epoch 178, minibatch 10/10, validation error 9.000000 %
# epoch 179, minibatch 10/10, validation error 9.000000 %
# epoch 180, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1800
# epoch 181, minibatch 10/10, validation error 9.000000 %
# epoch 182, minibatch 10/10, validation error 9.000000 %
# epoch 183, minibatch 10/10, validation error 9.000000 %
# epoch 184, minibatch 10/10, validation error 9.000000 %
# epoch 185, minibatch 10/10, validation error 9.000000 %
# epoch 186, minibatch 10/10, validation error 9.000000 %
# epoch 187, minibatch 10/10, validation error 9.000000 %
# epoch 188, minibatch 10/10, validation error 9.000000 %
# epoch 189, minibatch 10/10, validation error 9.000000 %
# epoch 190, minibatch 10/10, validation error 9.000000 %
# training @ iter =  1900
# epoch 191, minibatch 10/10, validation error 9.000000 %
# epoch 192, minibatch 10/10, validation error 9.000000 %
# epoch 193, minibatch 10/10, validation error 9.000000 %
# epoch 194, minibatch 10/10, validation error 9.000000 %
# epoch 195, minibatch 10/10, validation error 9.000000 %
# epoch 196, minibatch 10/10, validation error 9.000000 %
# epoch 197, minibatch 10/10, validation error 9.000000 %
# epoch 198, minibatch 10/10, validation error 9.000000 %
# epoch 199, minibatch 10/10, validation error 9.000000 %
# epoch 200, minibatch 10/10, validation error 9.000000 %
# Optimization complete.
# Best validation score of 7.000000 % obtained at iteration 210, with test performance 8.000000 %
# The code for file ran for 18.55m

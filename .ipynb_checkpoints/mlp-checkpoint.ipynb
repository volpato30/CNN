# %%
__docformat__ = 'restructedtext en'

import os
import sys
import timeit
import numpy
import theano
import theano.tensor as T
from logistic_sgd import LogisticRegression, load_data

class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out, W=None, b=None,
                 activation=T.tanh):
        """
        Typical hidden layer of a MLP: units are fully-connected and have
        sigmoidal activation function. Weight matrix W is of shape (n_in,n_out)
        and the bias vector b is of shape (n_out,).

        NOTE : The nonlinearity used here is tanh

        Hidden unit activation is given by: tanh(dot(input,W) + b)

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dmatrix
        :param input: a symbolic tensor of shape (n_examples, n_in)

        :type n_in: int
        :param n_in: dimensionality of input

        :type n_out: int
        :param n_out: number of hidden units

        :type activation: theano.Op or function
        :param activation: Non linearity to be applied in the hidden
                           layer
        """
        self.input = input
        # end-snippet-1

        # `W` is initialized with `W_values` which is uniformely sampled
        # from sqrt(-6./(n_in+n_hidden)) and sqrt(6./(n_in+n_hidden))
        # for tanh activation function
        # the output of uniform if converted using asarray to dtype
        # theano.config.floatX so that the code is runable on GPU
        # Note : optimal initialization of weights is dependent on the
        #        activation function used (among other things).
        #        For example, results presented in [Xavier10] suggest that you
        #        should use 4 times larger initial weights for sigmoid
        #        compared to tanh
        #        We have no info for other function, so we use the same as
        #        tanh.
        if W is None:
            W_values = numpy.asarray(
                rng.uniform(
                    low=-numpy.sqrt(6. / (n_in + n_out)),
                    high=numpy.sqrt(6. / (n_in + n_out)),
                    size=(n_in, n_out)
                ),
                dtype=theano.config.floatX
            )
            if activation == theano.tensor.nnet.sigmoid:
                W_values *= 4

            W = theano.shared(value=W_values, name='W', borrow=True)

        if b is None:
            b_values = numpy.zeros((n_out,), dtype=theano.config.floatX)
            b = theano.shared(value=b_values, name='b', borrow=True)

        self.W = W
        self.b = b

        lin_output = T.dot(input, self.W) + self.b
        self.output = (
            lin_output if activation is None
            else activation(lin_output)
        )
        # parameters of the model
        self.params = [self.W, self.b]

# %%
class MLP(object):
    """Multi-Layer Perceptron Class

    A multilayer perceptron is a feedforward artificial neural network model
    that has one layer or more of hidden units and nonlinear activations.
    Intermediate layers usually have as activation function tanh or the
    sigmoid function (defined here by a ``HiddenLayer`` class)  while the
    top layer is a softmax layer (defined here by a ``LogisticRegression``
    class).
    """

    def __init__(self, rng, input, n_in, n_hidden, n_out):
        """Initialize the parameters for the multilayer perceptron

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
        architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
        which the datapoints lie

        :type n_hidden: int
        :param n_hidden: number of hidden units

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
        which the labels lie

        """

        # Since we are dealing with a one hidden layer MLP, this will translate
        # into a HiddenLayer with a tanh activation function connected to the
        # LogisticRegression layer; the activation function can be replaced by
        # sigmoid or any other nonlinear function
        self.hiddenLayer = HiddenLayer(
            rng=rng,
            input=input,
            n_in=n_in,
            n_out=n_hidden,
            activation=T.tanh
        )

        # The logistic regression layer gets as input the hidden units
        # of the hidden layer
        self.logRegressionLayer = LogisticRegression(
            input=self.hiddenLayer.output,
            n_in=n_hidden,
            n_out=n_out
        )
        # L1 norm ; one regularization option is to enforce L1 norm to
        # be small
        self.L1 = (
            abs(self.hiddenLayer.W).sum()
            + abs(self.logRegressionLayer.W).sum()
        )

        # square of L2 norm ; one regularization option is to enforce
        # square of L2 norm to be small
        self.L2_sqr = (
            (self.hiddenLayer.W ** 2).sum()
            + (self.logRegressionLayer.W ** 2).sum()
        )

        # negative log likelihood of the MLP is given by the negative
        # log likelihood of the output of the model, computed in the
        # logistic regression layer
        self.negative_log_likelihood = (
            self.logRegressionLayer.negative_log_likelihood
        )
        # same holds for the function computing the number of errors
        self.errors = self.logRegressionLayer.errors

        # the parameters of the model are the parameters of the two layer it is
        # made out of
        self.params = self.hiddenLayer.params + self.logRegressionLayer.params
        # end-snippet-3

        # keep track of model input
        self.input = input

# %%
def test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=10000,
             batch_size=20, n_hidden=500):
    """
    Demonstrate stochastic gradient descent optimization for a multilayer
    perceptron
    
    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
    gradient

    :type L1_reg: float
    :param L1_reg: L1-norm's weight when added to the cost (see
    regularization)

    :type L2_reg: float
    :param L2_reg: L2-norm's weight when added to the cost (see
    regularization)

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: the path of the MNIST dataset file from
                 http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz


   """
    datasets = load_data()

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = int(train_set_x.get_value(borrow=True).shape[0] / batch_size)
    n_valid_batches = int(valid_set_x.get_value(borrow=True).shape[0] / batch_size)
    n_test_batches = int(test_set_x.get_value(borrow=True).shape[0] / batch_size)

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print('... building the model')

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch
    x = T.matrix('x')  # the data is presented as rasterized images
    y = T.ivector('y')  # the labels are presented as 1D vector of
                        # [int] labels

    rng = numpy.random.RandomState(1234)

    # construct the MLP class
    classifier = MLP(
        rng=rng,
        input=x,
        n_in=4096,
        n_hidden=n_hidden,
        n_out=40
    )

    # start-snippet-4
    # the cost we minimize during training is the negative log likelihood of
    # the model plus the regularization terms (L1 and L2); cost is expressed
    # here symbolically
    cost = (
        classifier.negative_log_likelihood(y)
        + L1_reg * classifier.L1
        + L2_reg * classifier.L2_sqr
    )
    # end-snippet-4

    # compiling a Theano function that computes the mistakes that are made
    # by the model on a minibatch
    test_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: test_set_x[index * batch_size:(index + 1) * batch_size],
            y: test_set_y[index * batch_size:(index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: valid_set_x[index * batch_size:(index + 1) * batch_size],
            y: valid_set_y[index * batch_size:(index + 1) * batch_size]
        }
    )

    # start-snippet-5
    # compute the gradient of cost with respect to theta (sotred in params)
    # the resulting gradients will be stored in a list gparams
    gparams = [T.grad(cost, param) for param in classifier.params]

    # specify how to update the parameters of the model as a list of
    # (variable, update expression) pairs

    # given two lists of the same length, A = [a1, a2, a3, a4] and
    # B = [b1, b2, b3, b4], zip generates a list C of same size, where each
    # element is a pair formed from the two lists :
    #    C = [(a1, b1), (a2, b2), (a3, b3), (a4, b4)]
    updates = [
        (param, param - learning_rate * gparam)
        for param, gparam in zip(classifier.params, gparams)
    ]

    # compiling a Theano function `train_model` that returns the cost, but
    # in the same time updates the parameter of the model based on the rules
    # defined in `updates`
    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )
    # end-snippet-5

    ###############
    # TRAIN MODEL #
    ###############
    print('... training')

    # early-stopping parameters
    patience = 300  # look as this many examples regardless
    patience_increase = 2  # wait this much longer when a new best is
                           # found
    improvement_threshold = 0.995  # a relative improvement of this much is
                                   # considered significant
    validation_frequency = min(n_train_batches, patience / 2)
                                  # go through this many
                                  # minibatche before checking the network
                                  # on the validation set; in this case we
                                  # check every epoch

    best_validation_loss = numpy.inf
    best_iter = 0
    test_score = 0.
    start_time = timeit.default_timer()

    epoch = 0
    done_looping = False

    while (epoch < n_epochs) and (not done_looping):
        epoch=epoch+1
        if epoch>500:
            learning_rate=0.001
        for minibatch_index in range(n_train_batches):

            minibatch_avg_cost = train_model(minibatch_index)
            # iteration number
            iter = (epoch - 1) * n_train_batches + minibatch_index

            if (iter + 1) % validation_frequency == 0:
                # compute zero-one loss on validation set
                validation_losses = [validate_model(i) for i
                                     in range(n_valid_batches)]
                this_validation_loss = numpy.mean(validation_losses)

                print((
                    'epoch %i, minibatch %i/%i, validation error %f %%' %
                    (
                        epoch,
                        minibatch_index + 1,
                        n_train_batches,
                        this_validation_loss * 100.
                    )
                ))

                # if we got the best validation score until now
                if this_validation_loss < best_validation_loss:
                    #improve patience if loss improvement is good enough
                    if (
                        this_validation_loss < best_validation_loss *
                        improvement_threshold
                    ):
                        patience = max(patience, iter * patience_increase)

                    best_validation_loss = this_validation_loss
                    best_iter = iter

                    # test it on the test set
                    test_losses = [test_model(i) for i
                                   in range(n_test_batches)]
                    test_score = numpy.mean(test_losses)

                    print((('     epoch %i, minibatch %i/%i, test error of '
                           'best model %f %%') %
                          (epoch, minibatch_index + 1, n_train_batches,
                           test_score * 100.)))

            if patience <= iter:
                done_looping = True
                break

    end_time = timeit.default_timer()
    print((('Optimization complete. Best validation score of %f %% '
           'obtained at iteration %i, with test performance %f %%') %
          (best_validation_loss * 100., best_iter + 1, test_score * 100.)))
    print(('The code ran for %.2fm' % ((end_time - start_time) / 60.)), file=sys.stderr)

# %%
test_mlp()
# Out:
# ... building the model
# ... training
# epoch 1, minibatch 10/10, validation error 92.000000 %
#      epoch 1, minibatch 10/10, test error of best model 96.000000 %
# epoch 2, minibatch 10/10, validation error 92.000000 %
# epoch 3, minibatch 10/10, validation error 93.000000 %
# epoch 4, minibatch 10/10, validation error 93.000000 %
# epoch 5, minibatch 10/10, validation error 93.000000 %
# epoch 6, minibatch 10/10, validation error 93.000000 %
# epoch 7, minibatch 10/10, validation error 93.000000 %
# epoch 8, minibatch 10/10, validation error 93.000000 %
# epoch 9, minibatch 10/10, validation error 93.000000 %
# epoch 10, minibatch 10/10, validation error 93.000000 %
# epoch 11, minibatch 10/10, validation error 92.000000 %
# epoch 12, minibatch 10/10, validation error 89.000000 %
#      epoch 12, minibatch 10/10, test error of best model 93.000000 %
# epoch 13, minibatch 10/10, validation error 89.000000 %
# epoch 14, minibatch 10/10, validation error 88.000000 %
#      epoch 14, minibatch 10/10, test error of best model 93.000000 %
# epoch 15, minibatch 10/10, validation error 83.000000 %
#      epoch 15, minibatch 10/10, test error of best model 93.000000 %
# epoch 16, minibatch 10/10, validation error 83.000000 %
# epoch 17, minibatch 10/10, validation error 82.000000 %
#      epoch 17, minibatch 10/10, test error of best model 89.000000 %
# epoch 18, minibatch 10/10, validation error 82.000000 %
# epoch 19, minibatch 10/10, validation error 81.000000 %
#      epoch 19, minibatch 10/10, test error of best model 86.000000 %
# epoch 20, minibatch 10/10, validation error 81.000000 %
# epoch 21, minibatch 10/10, validation error 81.000000 %
# epoch 22, minibatch 10/10, validation error 79.000000 %
#      epoch 22, minibatch 10/10, test error of best model 81.000000 %
# epoch 23, minibatch 10/10, validation error 79.000000 %
# epoch 24, minibatch 10/10, validation error 78.000000 %
#      epoch 24, minibatch 10/10, test error of best model 79.000000 %
# epoch 25, minibatch 10/10, validation error 77.000000 %
#      epoch 25, minibatch 10/10, test error of best model 79.000000 %
# epoch 26, minibatch 10/10, validation error 76.000000 %
#      epoch 26, minibatch 10/10, test error of best model 76.000000 %
# epoch 27, minibatch 10/10, validation error 76.000000 %
# epoch 28, minibatch 10/10, validation error 75.000000 %
#      epoch 28, minibatch 10/10, test error of best model 76.000000 %
# epoch 29, minibatch 10/10, validation error 75.000000 %
# epoch 30, minibatch 10/10, validation error 75.000000 %
# epoch 31, minibatch 10/10, validation error 72.000000 %
#      epoch 31, minibatch 10/10, test error of best model 75.000000 %
# epoch 32, minibatch 10/10, validation error 72.000000 %
# epoch 33, minibatch 10/10, validation error 73.000000 %
# epoch 34, minibatch 10/10, validation error 73.000000 %
# epoch 35, minibatch 10/10, validation error 72.000000 %
# epoch 36, minibatch 10/10, validation error 72.000000 %
# epoch 37, minibatch 10/10, validation error 71.000000 %
#      epoch 37, minibatch 10/10, test error of best model 72.000000 %
# epoch 38, minibatch 10/10, validation error 69.000000 %
#      epoch 38, minibatch 10/10, test error of best model 71.000000 %
# epoch 39, minibatch 10/10, validation error 69.000000 %
# epoch 40, minibatch 10/10, validation error 69.000000 %
# epoch 41, minibatch 10/10, validation error 68.000000 %
#      epoch 41, minibatch 10/10, test error of best model 69.000000 %
# epoch 42, minibatch 10/10, validation error 66.000000 %
#      epoch 42, minibatch 10/10, test error of best model 69.000000 %
# epoch 43, minibatch 10/10, validation error 66.000000 %
# epoch 44, minibatch 10/10, validation error 66.000000 %
# epoch 45, minibatch 10/10, validation error 66.000000 %
# epoch 46, minibatch 10/10, validation error 64.000000 %
#      epoch 46, minibatch 10/10, test error of best model 67.000000 %
# epoch 47, minibatch 10/10, validation error 64.000000 %
# epoch 48, minibatch 10/10, validation error 64.000000 %
# epoch 49, minibatch 10/10, validation error 64.000000 %
# epoch 50, minibatch 10/10, validation error 63.000000 %
#      epoch 50, minibatch 10/10, test error of best model 63.000000 %
# epoch 51, minibatch 10/10, validation error 63.000000 %
# epoch 52, minibatch 10/10, validation error 63.000000 %
# epoch 53, minibatch 10/10, validation error 61.000000 %
#      epoch 53, minibatch 10/10, test error of best model 59.000000 %
# epoch 54, minibatch 10/10, validation error 60.000000 %
#      epoch 54, minibatch 10/10, test error of best model 59.000000 %
# epoch 55, minibatch 10/10, validation error 59.000000 %
#      epoch 55, minibatch 10/10, test error of best model 57.000000 %
# epoch 56, minibatch 10/10, validation error 59.000000 %
# epoch 57, minibatch 10/10, validation error 58.000000 %
#      epoch 57, minibatch 10/10, test error of best model 57.000000 %
# epoch 58, minibatch 10/10, validation error 55.000000 %
#      epoch 58, minibatch 10/10, test error of best model 56.000000 %
# epoch 59, minibatch 10/10, validation error 55.000000 %
# epoch 60, minibatch 10/10, validation error 55.000000 %
# epoch 61, minibatch 10/10, validation error 55.000000 %
# epoch 62, minibatch 10/10, validation error 55.000000 %
# epoch 63, minibatch 10/10, validation error 55.000000 %
# epoch 64, minibatch 10/10, validation error 54.000000 %
#      epoch 64, minibatch 10/10, test error of best model 54.000000 %
# epoch 65, minibatch 10/10, validation error 54.000000 %
# epoch 66, minibatch 10/10, validation error 54.000000 %
# epoch 67, minibatch 10/10, validation error 53.000000 %
#      epoch 67, minibatch 10/10, test error of best model 54.000000 %
# epoch 68, minibatch 10/10, validation error 52.000000 %
#      epoch 68, minibatch 10/10, test error of best model 54.000000 %
# epoch 69, minibatch 10/10, validation error 51.000000 %
#      epoch 69, minibatch 10/10, test error of best model 53.000000 %
# epoch 70, minibatch 10/10, validation error 51.000000 %
# epoch 71, minibatch 10/10, validation error 51.000000 %
# epoch 72, minibatch 10/10, validation error 49.000000 %
#      epoch 72, minibatch 10/10, test error of best model 51.000000 %
# epoch 73, minibatch 10/10, validation error 48.000000 %
#      epoch 73, minibatch 10/10, test error of best model 51.000000 %
# epoch 74, minibatch 10/10, validation error 48.000000 %
# epoch 75, minibatch 10/10, validation error 48.000000 %
# epoch 76, minibatch 10/10, validation error 48.000000 %
# epoch 77, minibatch 10/10, validation error 46.000000 %
#      epoch 77, minibatch 10/10, test error of best model 49.000000 %
# epoch 78, minibatch 10/10, validation error 46.000000 %
# epoch 79, minibatch 10/10, validation error 46.000000 %
# epoch 80, minibatch 10/10, validation error 45.000000 %
#      epoch 80, minibatch 10/10, test error of best model 48.000000 %
# epoch 81, minibatch 10/10, validation error 44.000000 %
#      epoch 81, minibatch 10/10, test error of best model 48.000000 %
# epoch 82, minibatch 10/10, validation error 43.000000 %
#      epoch 82, minibatch 10/10, test error of best model 48.000000 %
# epoch 83, minibatch 10/10, validation error 43.000000 %
# epoch 84, minibatch 10/10, validation error 43.000000 %
# epoch 85, minibatch 10/10, validation error 43.000000 %
# epoch 86, minibatch 10/10, validation error 42.000000 %
#      epoch 86, minibatch 10/10, test error of best model 45.000000 %
# epoch 87, minibatch 10/10, validation error 42.000000 %
# epoch 88, minibatch 10/10, validation error 41.000000 %
#      epoch 88, minibatch 10/10, test error of best model 45.000000 %
# epoch 89, minibatch 10/10, validation error 40.000000 %
#      epoch 89, minibatch 10/10, test error of best model 44.000000 %
# epoch 90, minibatch 10/10, validation error 39.000000 %
#      epoch 90, minibatch 10/10, test error of best model 44.000000 %
# epoch 91, minibatch 10/10, validation error 39.000000 %
# epoch 92, minibatch 10/10, validation error 39.000000 %
# epoch 93, minibatch 10/10, validation error 39.000000 %
# epoch 94, minibatch 10/10, validation error 39.000000 %
# epoch 95, minibatch 10/10, validation error 38.000000 %
#      epoch 95, minibatch 10/10, test error of best model 42.000000 %
# epoch 96, minibatch 10/10, validation error 37.000000 %
#      epoch 96, minibatch 10/10, test error of best model 42.000000 %
# epoch 97, minibatch 10/10, validation error 35.000000 %
#      epoch 97, minibatch 10/10, test error of best model 40.000000 %
# epoch 98, minibatch 10/10, validation error 35.000000 %
# epoch 99, minibatch 10/10, validation error 35.000000 %
# epoch 100, minibatch 10/10, validation error 35.000000 %
# epoch 101, minibatch 10/10, validation error 35.000000 %
# epoch 102, minibatch 10/10, validation error 35.000000 %
# epoch 103, minibatch 10/10, validation error 34.000000 %
#      epoch 103, minibatch 10/10, test error of best model 38.000000 %
# epoch 104, minibatch 10/10, validation error 34.000000 %
# epoch 105, minibatch 10/10, validation error 34.000000 %
# epoch 106, minibatch 10/10, validation error 34.000000 %
# epoch 107, minibatch 10/10, validation error 34.000000 %
# epoch 108, minibatch 10/10, validation error 34.000000 %
# epoch 109, minibatch 10/10, validation error 33.000000 %
#      epoch 109, minibatch 10/10, test error of best model 38.000000 %
# epoch 110, minibatch 10/10, validation error 33.000000 %
# epoch 111, minibatch 10/10, validation error 33.000000 %
# epoch 112, minibatch 10/10, validation error 33.000000 %
# epoch 113, minibatch 10/10, validation error 33.000000 %
# epoch 114, minibatch 10/10, validation error 33.000000 %
# epoch 115, minibatch 10/10, validation error 33.000000 %
# epoch 116, minibatch 10/10, validation error 33.000000 %
# epoch 117, minibatch 10/10, validation error 32.000000 %
#      epoch 117, minibatch 10/10, test error of best model 36.000000 %
# epoch 118, minibatch 10/10, validation error 32.000000 %
# epoch 119, minibatch 10/10, validation error 32.000000 %
# epoch 120, minibatch 10/10, validation error 32.000000 %
# epoch 121, minibatch 10/10, validation error 32.000000 %
# epoch 122, minibatch 10/10, validation error 32.000000 %
# epoch 123, minibatch 10/10, validation error 32.000000 %
# epoch 124, minibatch 10/10, validation error 31.000000 %
#      epoch 124, minibatch 10/10, test error of best model 31.000000 %
# epoch 125, minibatch 10/10, validation error 31.000000 %
# epoch 126, minibatch 10/10, validation error 31.000000 %
# epoch 127, minibatch 10/10, validation error 31.000000 %
# epoch 128, minibatch 10/10, validation error 31.000000 %
# epoch 129, minibatch 10/10, validation error 31.000000 %
# epoch 130, minibatch 10/10, validation error 31.000000 %
# epoch 131, minibatch 10/10, validation error 31.000000 %
# epoch 132, minibatch 10/10, validation error 31.000000 %
# epoch 133, minibatch 10/10, validation error 30.000000 %
#      epoch 133, minibatch 10/10, test error of best model 29.000000 %
# epoch 134, minibatch 10/10, validation error 29.000000 %
#      epoch 134, minibatch 10/10, test error of best model 29.000000 %
# epoch 135, minibatch 10/10, validation error 29.000000 %
# epoch 136, minibatch 10/10, validation error 28.000000 %
#      epoch 136, minibatch 10/10, test error of best model 28.000000 %
# epoch 137, minibatch 10/10, validation error 28.000000 %
# epoch 138, minibatch 10/10, validation error 27.000000 %
#      epoch 138, minibatch 10/10, test error of best model 28.000000 %
# epoch 139, minibatch 10/10, validation error 27.000000 %
# epoch 140, minibatch 10/10, validation error 27.000000 %
# epoch 141, minibatch 10/10, validation error 27.000000 %
# epoch 142, minibatch 10/10, validation error 27.000000 %
# epoch 143, minibatch 10/10, validation error 27.000000 %
# epoch 144, minibatch 10/10, validation error 26.000000 %
#      epoch 144, minibatch 10/10, test error of best model 28.000000 %
# epoch 145, minibatch 10/10, validation error 25.000000 %
#      epoch 145, minibatch 10/10, test error of best model 27.000000 %
# epoch 146, minibatch 10/10, validation error 25.000000 %
# epoch 147, minibatch 10/10, validation error 25.000000 %
# epoch 148, minibatch 10/10, validation error 25.000000 %
# epoch 149, minibatch 10/10, validation error 25.000000 %
# epoch 150, minibatch 10/10, validation error 25.000000 %
# epoch 151, minibatch 10/10, validation error 25.000000 %
# epoch 152, minibatch 10/10, validation error 25.000000 %
# epoch 153, minibatch 10/10, validation error 25.000000 %
# epoch 154, minibatch 10/10, validation error 25.000000 %
# epoch 155, minibatch 10/10, validation error 25.000000 %
# epoch 156, minibatch 10/10, validation error 25.000000 %
# epoch 157, minibatch 10/10, validation error 25.000000 %
# epoch 158, minibatch 10/10, validation error 25.000000 %
# epoch 159, minibatch 10/10, validation error 25.000000 %
# epoch 160, minibatch 10/10, validation error 25.000000 %
# epoch 161, minibatch 10/10, validation error 25.000000 %
# epoch 162, minibatch 10/10, validation error 25.000000 %
# epoch 163, minibatch 10/10, validation error 25.000000 %
# epoch 164, minibatch 10/10, validation error 25.000000 %
# epoch 165, minibatch 10/10, validation error 25.000000 %
# epoch 166, minibatch 10/10, validation error 24.000000 %
#      epoch 166, minibatch 10/10, test error of best model 25.000000 %
# epoch 167, minibatch 10/10, validation error 24.000000 %
# epoch 168, minibatch 10/10, validation error 24.000000 %
# epoch 169, minibatch 10/10, validation error 24.000000 %
# epoch 170, minibatch 10/10, validation error 24.000000 %
# epoch 171, minibatch 10/10, validation error 24.000000 %
# epoch 172, minibatch 10/10, validation error 24.000000 %
# epoch 173, minibatch 10/10, validation error 23.000000 %
#      epoch 173, minibatch 10/10, test error of best model 24.000000 %
# epoch 174, minibatch 10/10, validation error 23.000000 %
# epoch 175, minibatch 10/10, validation error 23.000000 %
# epoch 176, minibatch 10/10, validation error 23.000000 %
# epoch 177, minibatch 10/10, validation error 23.000000 %
# epoch 178, minibatch 10/10, validation error 23.000000 %
# epoch 179, minibatch 10/10, validation error 23.000000 %
# epoch 180, minibatch 10/10, validation error 23.000000 %
# epoch 181, minibatch 10/10, validation error 23.000000 %
# epoch 182, minibatch 10/10, validation error 23.000000 %
# epoch 183, minibatch 10/10, validation error 22.000000 %
#      epoch 183, minibatch 10/10, test error of best model 24.000000 %
# epoch 184, minibatch 10/10, validation error 20.000000 %
#      epoch 184, minibatch 10/10, test error of best model 23.000000 %
# epoch 185, minibatch 10/10, validation error 20.000000 %
# epoch 186, minibatch 10/10, validation error 20.000000 %
# epoch 187, minibatch 10/10, validation error 20.000000 %
# epoch 188, minibatch 10/10, validation error 20.000000 %
# epoch 189, minibatch 10/10, validation error 20.000000 %
# epoch 190, minibatch 10/10, validation error 20.000000 %
# epoch 191, minibatch 10/10, validation error 20.000000 %
# epoch 192, minibatch 10/10, validation error 20.000000 %
# epoch 193, minibatch 10/10, validation error 20.000000 %
# epoch 194, minibatch 10/10, validation error 20.000000 %
# epoch 195, minibatch 10/10, validation error 20.000000 %
# epoch 196, minibatch 10/10, validation error 20.000000 %
# epoch 197, minibatch 10/10, validation error 20.000000 %
# epoch 198, minibatch 10/10, validation error 20.000000 %
# epoch 199, minibatch 10/10, validation error 20.000000 %
# epoch 200, minibatch 10/10, validation error 20.000000 %
# epoch 201, minibatch 10/10, validation error 20.000000 %
# epoch 202, minibatch 10/10, validation error 21.000000 %
# epoch 203, minibatch 10/10, validation error 21.000000 %
# epoch 204, minibatch 10/10, validation error 21.000000 %
# epoch 205, minibatch 10/10, validation error 21.000000 %
# epoch 206, minibatch 10/10, validation error 21.000000 %
# epoch 207, minibatch 10/10, validation error 21.000000 %
# epoch 208, minibatch 10/10, validation error 21.000000 %
# epoch 209, minibatch 10/10, validation error 21.000000 %
# epoch 210, minibatch 10/10, validation error 21.000000 %
# epoch 211, minibatch 10/10, validation error 21.000000 %
# epoch 212, minibatch 10/10, validation error 21.000000 %
# epoch 213, minibatch 10/10, validation error 21.000000 %
# epoch 214, minibatch 10/10, validation error 21.000000 %
# epoch 215, minibatch 10/10, validation error 21.000000 %
# epoch 216, minibatch 10/10, validation error 21.000000 %
# epoch 217, minibatch 10/10, validation error 21.000000 %
# epoch 218, minibatch 10/10, validation error 21.000000 %
# epoch 219, minibatch 10/10, validation error 21.000000 %
# epoch 220, minibatch 10/10, validation error 21.000000 %
# epoch 221, minibatch 10/10, validation error 21.000000 %
# epoch 222, minibatch 10/10, validation error 21.000000 %
# epoch 223, minibatch 10/10, validation error 21.000000 %
# epoch 224, minibatch 10/10, validation error 21.000000 %
# epoch 225, minibatch 10/10, validation error 21.000000 %
# epoch 226, minibatch 10/10, validation error 21.000000 %
# epoch 227, minibatch 10/10, validation error 21.000000 %
# epoch 228, minibatch 10/10, validation error 21.000000 %
# epoch 229, minibatch 10/10, validation error 21.000000 %
# epoch 230, minibatch 10/10, validation error 20.000000 %
# epoch 231, minibatch 10/10, validation error 20.000000 %
# epoch 232, minibatch 10/10, validation error 20.000000 %
# epoch 233, minibatch 10/10, validation error 20.000000 %
# epoch 234, minibatch 10/10, validation error 21.000000 %
# epoch 235, minibatch 10/10, validation error 21.000000 %
# epoch 236, minibatch 10/10, validation error 21.000000 %
# epoch 237, minibatch 10/10, validation error 21.000000 %
# epoch 238, minibatch 10/10, validation error 21.000000 %
# epoch 239, minibatch 10/10, validation error 21.000000 %
# epoch 240, minibatch 10/10, validation error 21.000000 %
# epoch 241, minibatch 10/10, validation error 21.000000 %
# epoch 242, minibatch 10/10, validation error 20.000000 %
# epoch 243, minibatch 10/10, validation error 18.000000 %
#      epoch 243, minibatch 10/10, test error of best model 17.000000 %
# epoch 244, minibatch 10/10, validation error 18.000000 %
# epoch 245, minibatch 10/10, validation error 18.000000 %
# epoch 246, minibatch 10/10, validation error 18.000000 %
# epoch 247, minibatch 10/10, validation error 18.000000 %
# epoch 248, minibatch 10/10, validation error 18.000000 %
# epoch 249, minibatch 10/10, validation error 18.000000 %
# epoch 250, minibatch 10/10, validation error 18.000000 %
# epoch 251, minibatch 10/10, validation error 18.000000 %
# epoch 252, minibatch 10/10, validation error 18.000000 %
# epoch 253, minibatch 10/10, validation error 18.000000 %
# epoch 254, minibatch 10/10, validation error 18.000000 %
# epoch 255, minibatch 10/10, validation error 18.000000 %
# epoch 256, minibatch 10/10, validation error 18.000000 %
# epoch 257, minibatch 10/10, validation error 18.000000 %
# epoch 258, minibatch 10/10, validation error 18.000000 %
# epoch 259, minibatch 10/10, validation error 18.000000 %
# epoch 260, minibatch 10/10, validation error 18.000000 %
# epoch 261, minibatch 10/10, validation error 18.000000 %
# epoch 262, minibatch 10/10, validation error 18.000000 %
# epoch 263, minibatch 10/10, validation error 17.000000 %
#      epoch 263, minibatch 10/10, test error of best model 16.000000 %
# epoch 264, minibatch 10/10, validation error 17.000000 %
# epoch 265, minibatch 10/10, validation error 16.000000 %
#      epoch 265, minibatch 10/10, test error of best model 16.000000 %
# epoch 266, minibatch 10/10, validation error 16.000000 %
# epoch 267, minibatch 10/10, validation error 16.000000 %
# epoch 268, minibatch 10/10, validation error 16.000000 %
# epoch 269, minibatch 10/10, validation error 16.000000 %
# epoch 270, minibatch 10/10, validation error 16.000000 %
# epoch 271, minibatch 10/10, validation error 16.000000 %
# epoch 272, minibatch 10/10, validation error 16.000000 %
# epoch 273, minibatch 10/10, validation error 16.000000 %
# epoch 274, minibatch 10/10, validation error 16.000000 %
# epoch 275, minibatch 10/10, validation error 16.000000 %
# epoch 276, minibatch 10/10, validation error 16.000000 %
# epoch 277, minibatch 10/10, validation error 16.000000 %
# epoch 278, minibatch 10/10, validation error 16.000000 %
# epoch 279, minibatch 10/10, validation error 16.000000 %
# epoch 280, minibatch 10/10, validation error 16.000000 %
# epoch 281, minibatch 10/10, validation error 16.000000 %
# epoch 282, minibatch 10/10, validation error 15.000000 %
#      epoch 282, minibatch 10/10, test error of best model 16.000000 %
# epoch 283, minibatch 10/10, validation error 15.000000 %
# epoch 284, minibatch 10/10, validation error 15.000000 %
# epoch 285, minibatch 10/10, validation error 15.000000 %
# epoch 286, minibatch 10/10, validation error 15.000000 %
# epoch 287, minibatch 10/10, validation error 15.000000 %
# epoch 288, minibatch 10/10, validation error 15.000000 %
# epoch 289, minibatch 10/10, validation error 15.000000 %
# epoch 290, minibatch 10/10, validation error 15.000000 %
# epoch 291, minibatch 10/10, validation error 15.000000 %
# epoch 292, minibatch 10/10, validation error 15.000000 %
# epoch 293, minibatch 10/10, validation error 15.000000 %
# epoch 294, minibatch 10/10, validation error 15.000000 %
# epoch 295, minibatch 10/10, validation error 15.000000 %
# epoch 296, minibatch 10/10, validation error 15.000000 %
# epoch 297, minibatch 10/10, validation error 15.000000 %
# epoch 298, minibatch 10/10, validation error 15.000000 %
# epoch 299, minibatch 10/10, validation error 15.000000 %
# epoch 300, minibatch 10/10, validation error 15.000000 %
# epoch 301, minibatch 10/10, validation error 15.000000 %
# epoch 302, minibatch 10/10, validation error 15.000000 %
# epoch 303, minibatch 10/10, validation error 15.000000 %
# epoch 304, minibatch 10/10, validation error 15.000000 %
# epoch 305, minibatch 10/10, validation error 15.000000 %
# epoch 306, minibatch 10/10, validation error 15.000000 %
# epoch 307, minibatch 10/10, validation error 15.000000 %
# epoch 308, minibatch 10/10, validation error 15.000000 %
# epoch 309, minibatch 10/10, validation error 15.000000 %
# epoch 310, minibatch 10/10, validation error 15.000000 %
# epoch 311, minibatch 10/10, validation error 15.000000 %
# epoch 312, minibatch 10/10, validation error 15.000000 %
# epoch 313, minibatch 10/10, validation error 15.000000 %
# epoch 314, minibatch 10/10, validation error 15.000000 %
# epoch 315, minibatch 10/10, validation error 15.000000 %
# epoch 316, minibatch 10/10, validation error 15.000000 %
# epoch 317, minibatch 10/10, validation error 15.000000 %
# epoch 318, minibatch 10/10, validation error 15.000000 %
# epoch 319, minibatch 10/10, validation error 15.000000 %
# epoch 320, minibatch 10/10, validation error 15.000000 %
# epoch 321, minibatch 10/10, validation error 15.000000 %
# epoch 322, minibatch 10/10, validation error 15.000000 %
# epoch 323, minibatch 10/10, validation error 15.000000 %
# epoch 324, minibatch 10/10, validation error 15.000000 %
# epoch 325, minibatch 10/10, validation error 15.000000 %
# epoch 326, minibatch 10/10, validation error 15.000000 %
# epoch 327, minibatch 10/10, validation error 15.000000 %
# epoch 328, minibatch 10/10, validation error 15.000000 %
# epoch 329, minibatch 10/10, validation error 15.000000 %
# epoch 330, minibatch 10/10, validation error 15.000000 %
# epoch 331, minibatch 10/10, validation error 15.000000 %
# epoch 332, minibatch 10/10, validation error 15.000000 %
# epoch 333, minibatch 10/10, validation error 15.000000 %
# epoch 334, minibatch 10/10, validation error 15.000000 %
# epoch 335, minibatch 10/10, validation error 15.000000 %
# epoch 336, minibatch 10/10, validation error 15.000000 %
# epoch 337, minibatch 10/10, validation error 15.000000 %
# epoch 338, minibatch 10/10, validation error 15.000000 %
# epoch 339, minibatch 10/10, validation error 15.000000 %
# epoch 340, minibatch 10/10, validation error 15.000000 %
# epoch 341, minibatch 10/10, validation error 15.000000 %
# epoch 342, minibatch 10/10, validation error 15.000000 %
# epoch 343, minibatch 10/10, validation error 15.000000 %
# epoch 344, minibatch 10/10, validation error 15.000000 %
# epoch 345, minibatch 10/10, validation error 15.000000 %
# epoch 346, minibatch 10/10, validation error 15.000000 %
# epoch 347, minibatch 10/10, validation error 15.000000 %
# epoch 348, minibatch 10/10, validation error 15.000000 %
# epoch 349, minibatch 10/10, validation error 15.000000 %
# epoch 350, minibatch 10/10, validation error 15.000000 %
# epoch 351, minibatch 10/10, validation error 15.000000 %
# epoch 352, minibatch 10/10, validation error 15.000000 %
# epoch 353, minibatch 10/10, validation error 15.000000 %
# epoch 354, minibatch 10/10, validation error 15.000000 %
# epoch 355, minibatch 10/10, validation error 15.000000 %
# epoch 356, minibatch 10/10, validation error 15.000000 %
# epoch 357, minibatch 10/10, validation error 15.000000 %
# epoch 358, minibatch 10/10, validation error 15.000000 %
# epoch 359, minibatch 10/10, validation error 15.000000 %
# epoch 360, minibatch 10/10, validation error 15.000000 %
# epoch 361, minibatch 10/10, validation error 15.000000 %
# epoch 362, minibatch 10/10, validation error 15.000000 %
# epoch 363, minibatch 10/10, validation error 15.000000 %
# epoch 364, minibatch 10/10, validation error 14.000000 %
#      epoch 364, minibatch 10/10, test error of best model 14.000000 %
# epoch 365, minibatch 10/10, validation error 14.000000 %
# epoch 366, minibatch 10/10, validation error 14.000000 %
# epoch 367, minibatch 10/10, validation error 13.000000 %
#      epoch 367, minibatch 10/10, test error of best model 14.000000 %
# epoch 368, minibatch 10/10, validation error 13.000000 %
# epoch 369, minibatch 10/10, validation error 13.000000 %
# epoch 370, minibatch 10/10, validation error 13.000000 %
# epoch 371, minibatch 10/10, validation error 13.000000 %
# epoch 372, minibatch 10/10, validation error 13.000000 %
# epoch 373, minibatch 10/10, validation error 13.000000 %
# epoch 374, minibatch 10/10, validation error 13.000000 %
# epoch 375, minibatch 10/10, validation error 13.000000 %
# epoch 376, minibatch 10/10, validation error 13.000000 %
# epoch 377, minibatch 10/10, validation error 13.000000 %
# epoch 378, minibatch 10/10, validation error 13.000000 %
# epoch 379, minibatch 10/10, validation error 13.000000 %
# epoch 380, minibatch 10/10, validation error 13.000000 %
# epoch 381, minibatch 10/10, validation error 13.000000 %
# epoch 382, minibatch 10/10, validation error 13.000000 %
# epoch 383, minibatch 10/10, validation error 13.000000 %
# epoch 384, minibatch 10/10, validation error 13.000000 %
# epoch 385, minibatch 10/10, validation error 13.000000 %
# epoch 386, minibatch 10/10, validation error 13.000000 %
# epoch 387, minibatch 10/10, validation error 13.000000 %
# epoch 388, minibatch 10/10, validation error 13.000000 %
# epoch 389, minibatch 10/10, validation error 13.000000 %
# epoch 390, minibatch 10/10, validation error 13.000000 %
# epoch 391, minibatch 10/10, validation error 13.000000 %
# epoch 392, minibatch 10/10, validation error 13.000000 %
# epoch 393, minibatch 10/10, validation error 13.000000 %
# epoch 394, minibatch 10/10, validation error 13.000000 %
# epoch 395, minibatch 10/10, validation error 13.000000 %
# epoch 396, minibatch 10/10, validation error 13.000000 %
# epoch 397, minibatch 10/10, validation error 13.000000 %
# epoch 398, minibatch 10/10, validation error 13.000000 %
# epoch 399, minibatch 10/10, validation error 13.000000 %
# epoch 400, minibatch 10/10, validation error 13.000000 %
# epoch 401, minibatch 10/10, validation error 13.000000 %
# epoch 402, minibatch 10/10, validation error 13.000000 %
# epoch 403, minibatch 10/10, validation error 12.000000 %
#      epoch 403, minibatch 10/10, test error of best model 12.000000 %
# epoch 404, minibatch 10/10, validation error 12.000000 %
# epoch 405, minibatch 10/10, validation error 12.000000 %
# epoch 406, minibatch 10/10, validation error 12.000000 %
# epoch 407, minibatch 10/10, validation error 12.000000 %
# epoch 408, minibatch 10/10, validation error 12.000000 %
# epoch 409, minibatch 10/10, validation error 12.000000 %
# epoch 410, minibatch 10/10, validation error 12.000000 %
# epoch 411, minibatch 10/10, validation error 12.000000 %
# epoch 412, minibatch 10/10, validation error 12.000000 %
# epoch 413, minibatch 10/10, validation error 12.000000 %
# epoch 414, minibatch 10/10, validation error 12.000000 %
# epoch 415, minibatch 10/10, validation error 11.000000 %
#      epoch 415, minibatch 10/10, test error of best model 12.000000 %
# epoch 416, minibatch 10/10, validation error 11.000000 %
# epoch 417, minibatch 10/10, validation error 11.000000 %
# epoch 418, minibatch 10/10, validation error 11.000000 %
# epoch 419, minibatch 10/10, validation error 11.000000 %
# epoch 420, minibatch 10/10, validation error 11.000000 %
# epoch 421, minibatch 10/10, validation error 11.000000 %
# epoch 422, minibatch 10/10, validation error 11.000000 %
# epoch 423, minibatch 10/10, validation error 11.000000 %
# epoch 424, minibatch 10/10, validation error 11.000000 %
# epoch 425, minibatch 10/10, validation error 11.000000 %
# epoch 426, minibatch 10/10, validation error 11.000000 %
# epoch 427, minibatch 10/10, validation error 11.000000 %
# epoch 428, minibatch 10/10, validation error 11.000000 %
# epoch 429, minibatch 10/10, validation error 11.000000 %
# epoch 430, minibatch 10/10, validation error 11.000000 %
# epoch 431, minibatch 10/10, validation error 11.000000 %
# epoch 432, minibatch 10/10, validation error 11.000000 %
# epoch 433, minibatch 10/10, validation error 11.000000 %
# epoch 434, minibatch 10/10, validation error 11.000000 %
# epoch 435, minibatch 10/10, validation error 11.000000 %
# epoch 436, minibatch 10/10, validation error 11.000000 %
# epoch 437, minibatch 10/10, validation error 11.000000 %
# epoch 438, minibatch 10/10, validation error 11.000000 %
# epoch 439, minibatch 10/10, validation error 11.000000 %
# epoch 440, minibatch 10/10, validation error 11.000000 %
# epoch 441, minibatch 10/10, validation error 11.000000 %
# epoch 442, minibatch 10/10, validation error 11.000000 %
# epoch 443, minibatch 10/10, validation error 11.000000 %
# epoch 444, minibatch 10/10, validation error 11.000000 %
# epoch 445, minibatch 10/10, validation error 11.000000 %
# epoch 446, minibatch 10/10, validation error 11.000000 %
# epoch 447, minibatch 10/10, validation error 11.000000 %
# epoch 448, minibatch 10/10, validation error 11.000000 %
# epoch 449, minibatch 10/10, validation error 11.000000 %
# epoch 450, minibatch 10/10, validation error 11.000000 %
# epoch 451, minibatch 10/10, validation error 11.000000 %
# epoch 452, minibatch 10/10, validation error 11.000000 %
# epoch 453, minibatch 10/10, validation error 11.000000 %
# epoch 454, minibatch 10/10, validation error 11.000000 %
# epoch 455, minibatch 10/10, validation error 11.000000 %
# epoch 456, minibatch 10/10, validation error 11.000000 %
# epoch 457, minibatch 10/10, validation error 11.000000 %
# epoch 458, minibatch 10/10, validation error 11.000000 %
# epoch 459, minibatch 10/10, validation error 11.000000 %
# epoch 460, minibatch 10/10, validation error 11.000000 %
# epoch 461, minibatch 10/10, validation error 11.000000 %
# epoch 462, minibatch 10/10, validation error 11.000000 %
# epoch 463, minibatch 10/10, validation error 11.000000 %
# epoch 464, minibatch 10/10, validation error 11.000000 %
# epoch 465, minibatch 10/10, validation error 11.000000 %
# epoch 466, minibatch 10/10, validation error 11.000000 %
# epoch 467, minibatch 10/10, validation error 11.000000 %
# epoch 468, minibatch 10/10, validation error 11.000000 %
# epoch 469, minibatch 10/10, validation error 11.000000 %
# epoch 470, minibatch 10/10, validation error 11.000000 %
# epoch 471, minibatch 10/10, validation error 11.000000 %
# epoch 472, minibatch 10/10, validation error 11.000000 %
# epoch 473, minibatch 10/10, validation error 11.000000 %
# epoch 474, minibatch 10/10, validation error 11.000000 %
# epoch 475, minibatch 10/10, validation error 11.000000 %
# epoch 476, minibatch 10/10, validation error 11.000000 %
# epoch 477, minibatch 10/10, validation error 11.000000 %
# epoch 478, minibatch 10/10, validation error 11.000000 %
# epoch 479, minibatch 10/10, validation error 11.000000 %
# epoch 480, minibatch 10/10, validation error 11.000000 %
# epoch 481, minibatch 10/10, validation error 11.000000 %
# epoch 482, minibatch 10/10, validation error 11.000000 %
# epoch 483, minibatch 10/10, validation error 11.000000 %
# epoch 484, minibatch 10/10, validation error 11.000000 %
# epoch 485, minibatch 10/10, validation error 11.000000 %
# epoch 486, minibatch 10/10, validation error 11.000000 %
# epoch 487, minibatch 10/10, validation error 11.000000 %
# epoch 488, minibatch 10/10, validation error 11.000000 %
# epoch 489, minibatch 10/10, validation error 11.000000 %
# epoch 490, minibatch 10/10, validation error 11.000000 %
# epoch 491, minibatch 10/10, validation error 11.000000 %
# epoch 492, minibatch 10/10, validation error 11.000000 %
# epoch 493, minibatch 10/10, validation error 11.000000 %
# epoch 494, minibatch 10/10, validation error 11.000000 %
# epoch 495, minibatch 10/10, validation error 11.000000 %
# epoch 496, minibatch 10/10, validation error 11.000000 %
# epoch 497, minibatch 10/10, validation error 11.000000 %
# epoch 498, minibatch 10/10, validation error 11.000000 %
# epoch 499, minibatch 10/10, validation error 11.000000 %
# epoch 500, minibatch 10/10, validation error 11.000000 %
# epoch 501, minibatch 10/10, validation error 11.000000 %
# epoch 502, minibatch 10/10, validation error 11.000000 %
# epoch 503, minibatch 10/10, validation error 11.000000 %
# epoch 504, minibatch 10/10, validation error 11.000000 %
# epoch 505, minibatch 10/10, validation error 11.000000 %
# epoch 506, minibatch 10/10, validation error 11.000000 %
# epoch 507, minibatch 10/10, validation error 11.000000 %
# epoch 508, minibatch 10/10, validation error 11.000000 %
# epoch 509, minibatch 10/10, validation error 11.000000 %
# epoch 510, minibatch 10/10, validation error 11.000000 %
# epoch 511, minibatch 10/10, validation error 11.000000 %
# epoch 512, minibatch 10/10, validation error 11.000000 %
# epoch 513, minibatch 10/10, validation error 11.000000 %
# epoch 514, minibatch 10/10, validation error 11.000000 %
# epoch 515, minibatch 10/10, validation error 11.000000 %
# epoch 516, minibatch 10/10, validation error 11.000000 %
# epoch 517, minibatch 10/10, validation error 11.000000 %
# epoch 518, minibatch 10/10, validation error 11.000000 %
# epoch 519, minibatch 10/10, validation error 11.000000 %
# epoch 520, minibatch 10/10, validation error 11.000000 %
# epoch 521, minibatch 10/10, validation error 11.000000 %
# epoch 522, minibatch 10/10, validation error 11.000000 %
# epoch 523, minibatch 10/10, validation error 11.000000 %
# epoch 524, minibatch 10/10, validation error 11.000000 %
# epoch 525, minibatch 10/10, validation error 11.000000 %
# epoch 526, minibatch 10/10, validation error 11.000000 %
# epoch 527, minibatch 10/10, validation error 11.000000 %
# epoch 528, minibatch 10/10, validation error 11.000000 %
# epoch 529, minibatch 10/10, validation error 11.000000 %
# epoch 530, minibatch 10/10, validation error 11.000000 %
# epoch 531, minibatch 10/10, validation error 11.000000 %
# epoch 532, minibatch 10/10, validation error 11.000000 %
# epoch 533, minibatch 10/10, validation error 11.000000 %
# epoch 534, minibatch 10/10, validation error 11.000000 %
# epoch 535, minibatch 10/10, validation error 11.000000 %
# epoch 536, minibatch 10/10, validation error 11.000000 %
# epoch 537, minibatch 10/10, validation error 11.000000 %
# epoch 538, minibatch 10/10, validation error 11.000000 %
# epoch 539, minibatch 10/10, validation error 11.000000 %
# epoch 540, minibatch 10/10, validation error 11.000000 %
# epoch 541, minibatch 10/10, validation error 11.000000 %
# epoch 542, minibatch 10/10, validation error 11.000000 %
# epoch 543, minibatch 10/10, validation error 11.000000 %
# epoch 544, minibatch 10/10, validation error 11.000000 %
# epoch 545, minibatch 10/10, validation error 11.000000 %
# epoch 546, minibatch 10/10, validation error 11.000000 %
# epoch 547, minibatch 10/10, validation error 11.000000 %
# epoch 548, minibatch 10/10, validation error 11.000000 %
# epoch 549, minibatch 10/10, validation error 11.000000 %
# epoch 550, minibatch 10/10, validation error 11.000000 %
# epoch 551, minibatch 10/10, validation error 11.000000 %
# epoch 552, minibatch 10/10, validation error 11.000000 %
# epoch 553, minibatch 10/10, validation error 11.000000 %
# epoch 554, minibatch 10/10, validation error 11.000000 %
# epoch 555, minibatch 10/10, validation error 11.000000 %
# epoch 556, minibatch 10/10, validation error 11.000000 %
# epoch 557, minibatch 10/10, validation error 11.000000 %
# epoch 558, minibatch 10/10, validation error 11.000000 %
# epoch 559, minibatch 10/10, validation error 11.000000 %
# epoch 560, minibatch 10/10, validation error 11.000000 %
# epoch 561, minibatch 10/10, validation error 11.000000 %
# epoch 562, minibatch 10/10, validation error 11.000000 %
# epoch 563, minibatch 10/10, validation error 11.000000 %
# epoch 564, minibatch 10/10, validation error 11.000000 %
# epoch 565, minibatch 10/10, validation error 11.000000 %
# epoch 566, minibatch 10/10, validation error 11.000000 %
# epoch 567, minibatch 10/10, validation error 11.000000 %
# epoch 568, minibatch 10/10, validation error 11.000000 %
# epoch 569, minibatch 10/10, validation error 11.000000 %
# epoch 570, minibatch 10/10, validation error 11.000000 %
# epoch 571, minibatch 10/10, validation error 11.000000 %
# epoch 572, minibatch 10/10, validation error 11.000000 %
# epoch 573, minibatch 10/10, validation error 11.000000 %
# epoch 574, minibatch 10/10, validation error 11.000000 %
# epoch 575, minibatch 10/10, validation error 11.000000 %
# epoch 576, minibatch 10/10, validation error 11.000000 %
# epoch 577, minibatch 10/10, validation error 11.000000 %
# epoch 578, minibatch 10/10, validation error 11.000000 %
# epoch 579, minibatch 10/10, validation error 11.000000 %
# epoch 580, minibatch 10/10, validation error 11.000000 %
# epoch 581, minibatch 10/10, validation error 11.000000 %
# epoch 582, minibatch 10/10, validation error 11.000000 %
# epoch 583, minibatch 10/10, validation error 11.000000 %
# epoch 584, minibatch 10/10, validation error 11.000000 %
# epoch 585, minibatch 10/10, validation error 11.000000 %
# epoch 586, minibatch 10/10, validation error 11.000000 %
# epoch 587, minibatch 10/10, validation error 11.000000 %
# epoch 588, minibatch 10/10, validation error 11.000000 %
# epoch 589, minibatch 10/10, validation error 11.000000 %
# epoch 590, minibatch 10/10, validation error 11.000000 %
# epoch 591, minibatch 10/10, validation error 11.000000 %
# epoch 592, minibatch 10/10, validation error 11.000000 %
# epoch 593, minibatch 10/10, validation error 11.000000 %
# epoch 594, minibatch 10/10, validation error 11.000000 %
# epoch 595, minibatch 10/10, validation error 11.000000 %
# epoch 596, minibatch 10/10, validation error 11.000000 %
# epoch 597, minibatch 10/10, validation error 11.000000 %
# epoch 598, minibatch 10/10, validation error 11.000000 %
# epoch 599, minibatch 10/10, validation error 11.000000 %
# epoch 600, minibatch 10/10, validation error 11.000000 %
# epoch 601, minibatch 10/10, validation error 11.000000 %
# epoch 602, minibatch 10/10, validation error 11.000000 %
# epoch 603, minibatch 10/10, validation error 11.000000 %
# epoch 604, minibatch 10/10, validation error 11.000000 %
# epoch 605, minibatch 10/10, validation error 11.000000 %
# epoch 606, minibatch 10/10, validation error 11.000000 %
# epoch 607, minibatch 10/10, validation error 11.000000 %
# epoch 608, minibatch 10/10, validation error 11.000000 %
# epoch 609, minibatch 10/10, validation error 11.000000 %
# epoch 610, minibatch 10/10, validation error 11.000000 %
# epoch 611, minibatch 10/10, validation error 11.000000 %
# epoch 612, minibatch 10/10, validation error 11.000000 %
# epoch 613, minibatch 10/10, validation error 11.000000 %
# epoch 614, minibatch 10/10, validation error 11.000000 %
# epoch 615, minibatch 10/10, validation error 11.000000 %
# epoch 616, minibatch 10/10, validation error 11.000000 %
# epoch 617, minibatch 10/10, validation error 11.000000 %
# epoch 618, minibatch 10/10, validation error 11.000000 %
# epoch 619, minibatch 10/10, validation error 11.000000 %
# epoch 620, minibatch 10/10, validation error 11.000000 %
# epoch 621, minibatch 10/10, validation error 11.000000 %
# epoch 622, minibatch 10/10, validation error 11.000000 %
# epoch 623, minibatch 10/10, validation error 11.000000 %
# epoch 624, minibatch 10/10, validation error 11.000000 %
# epoch 625, minibatch 10/10, validation error 11.000000 %
# epoch 626, minibatch 10/10, validation error 11.000000 %
# epoch 627, minibatch 10/10, validation error 11.000000 %
# epoch 628, minibatch 10/10, validation error 11.000000 %
# epoch 629, minibatch 10/10, validation error 11.000000 %
# epoch 630, minibatch 10/10, validation error 11.000000 %
# epoch 631, minibatch 10/10, validation error 11.000000 %
# epoch 632, minibatch 10/10, validation error 11.000000 %
# epoch 633, minibatch 10/10, validation error 11.000000 %
# epoch 634, minibatch 10/10, validation error 11.000000 %
# epoch 635, minibatch 10/10, validation error 11.000000 %
# epoch 636, minibatch 10/10, validation error 11.000000 %
# epoch 637, minibatch 10/10, validation error 11.000000 %
# epoch 638, minibatch 10/10, validation error 11.000000 %
# epoch 639, minibatch 10/10, validation error 11.000000 %
# epoch 640, minibatch 10/10, validation error 11.000000 %
# epoch 641, minibatch 10/10, validation error 11.000000 %
# epoch 642, minibatch 10/10, validation error 11.000000 %
# epoch 643, minibatch 10/10, validation error 11.000000 %
# epoch 644, minibatch 10/10, validation error 11.000000 %
# epoch 645, minibatch 10/10, validation error 11.000000 %
# epoch 646, minibatch 10/10, validation error 11.000000 %
# epoch 647, minibatch 10/10, validation error 11.000000 %
# epoch 648, minibatch 10/10, validation error 11.000000 %
# epoch 649, minibatch 10/10, validation error 11.000000 %
# epoch 650, minibatch 10/10, validation error 11.000000 %
# epoch 651, minibatch 10/10, validation error 11.000000 %
# epoch 652, minibatch 10/10, validation error 11.000000 %
# epoch 653, minibatch 10/10, validation error 11.000000 %
# epoch 654, minibatch 10/10, validation error 11.000000 %
# epoch 655, minibatch 10/10, validation error 11.000000 %
# epoch 656, minibatch 10/10, validation error 11.000000 %
# epoch 657, minibatch 10/10, validation error 11.000000 %
# epoch 658, minibatch 10/10, validation error 11.000000 %
# epoch 659, minibatch 10/10, validation error 11.000000 %
# epoch 660, minibatch 10/10, validation error 11.000000 %
# epoch 661, minibatch 10/10, validation error 11.000000 %
# epoch 662, minibatch 10/10, validation error 11.000000 %
# epoch 663, minibatch 10/10, validation error 11.000000 %
# epoch 664, minibatch 10/10, validation error 11.000000 %
# epoch 665, minibatch 10/10, validation error 11.000000 %
# epoch 666, minibatch 10/10, validation error 11.000000 %
# epoch 667, minibatch 10/10, validation error 11.000000 %
# epoch 668, minibatch 10/10, validation error 11.000000 %
# epoch 669, minibatch 10/10, validation error 11.000000 %
# epoch 670, minibatch 10/10, validation error 11.000000 %
# epoch 671, minibatch 10/10, validation error 11.000000 %
# epoch 672, minibatch 10/10, validation error 11.000000 %
# epoch 673, minibatch 10/10, validation error 11.000000 %
# epoch 674, minibatch 10/10, validation error 11.000000 %
# epoch 675, minibatch 10/10, validation error 11.000000 %
# epoch 676, minibatch 10/10, validation error 11.000000 %
# epoch 677, minibatch 10/10, validation error 11.000000 %
# epoch 678, minibatch 10/10, validation error 11.000000 %
# epoch 679, minibatch 10/10, validation error 11.000000 %
# epoch 680, minibatch 10/10, validation error 11.000000 %
# epoch 681, minibatch 10/10, validation error 11.000000 %
# epoch 682, minibatch 10/10, validation error 11.000000 %
# epoch 683, minibatch 10/10, validation error 11.000000 %
# epoch 684, minibatch 10/10, validation error 11.000000 %
# epoch 685, minibatch 10/10, validation error 11.000000 %
# epoch 686, minibatch 10/10, validation error 11.000000 %
# epoch 687, minibatch 10/10, validation error 11.000000 %
# epoch 688, minibatch 10/10, validation error 11.000000 %
# epoch 689, minibatch 10/10, validation error 11.000000 %
# epoch 690, minibatch 10/10, validation error 11.000000 %
# epoch 691, minibatch 10/10, validation error 11.000000 %
# epoch 692, minibatch 10/10, validation error 11.000000 %
# epoch 693, minibatch 10/10, validation error 11.000000 %
# epoch 694, minibatch 10/10, validation error 11.000000 %
# epoch 695, minibatch 10/10, validation error 11.000000 %
# epoch 696, minibatch 10/10, validation error 11.000000 %
# epoch 697, minibatch 10/10, validation error 11.000000 %
# epoch 698, minibatch 10/10, validation error 11.000000 %
# epoch 699, minibatch 10/10, validation error 11.000000 %
# epoch 700, minibatch 10/10, validation error 11.000000 %
# epoch 701, minibatch 10/10, validation error 11.000000 %
# epoch 702, minibatch 10/10, validation error 11.000000 %
# epoch 703, minibatch 10/10, validation error 11.000000 %
# epoch 704, minibatch 10/10, validation error 11.000000 %
# epoch 705, minibatch 10/10, validation error 11.000000 %
# epoch 706, minibatch 10/10, validation error 11.000000 %
# epoch 707, minibatch 10/10, validation error 11.000000 %
# epoch 708, minibatch 10/10, validation error 11.000000 %
# epoch 709, minibatch 10/10, validation error 11.000000 %
# epoch 710, minibatch 10/10, validation error 11.000000 %
# epoch 711, minibatch 10/10, validation error 11.000000 %
# epoch 712, minibatch 10/10, validation error 11.000000 %
# epoch 713, minibatch 10/10, validation error 11.000000 %
# epoch 714, minibatch 10/10, validation error 11.000000 %
# epoch 715, minibatch 10/10, validation error 11.000000 %
# epoch 716, minibatch 10/10, validation error 11.000000 %
# epoch 717, minibatch 10/10, validation error 11.000000 %
# epoch 718, minibatch 10/10, validation error 11.000000 %
# epoch 719, minibatch 10/10, validation error 11.000000 %
# epoch 720, minibatch 10/10, validation error 11.000000 %
# epoch 721, minibatch 10/10, validation error 11.000000 %
# epoch 722, minibatch 10/10, validation error 11.000000 %
# epoch 723, minibatch 10/10, validation error 11.000000 %
# epoch 724, minibatch 10/10, validation error 11.000000 %
# epoch 725, minibatch 10/10, validation error 11.000000 %
# epoch 726, minibatch 10/10, validation error 11.000000 %
# epoch 727, minibatch 10/10, validation error 11.000000 %
# epoch 728, minibatch 10/10, validation error 11.000000 %
# epoch 729, minibatch 10/10, validation error 11.000000 %
# epoch 730, minibatch 10/10, validation error 11.000000 %
# epoch 731, minibatch 10/10, validation error 11.000000 %
# epoch 732, minibatch 10/10, validation error 11.000000 %
# epoch 733, minibatch 10/10, validation error 11.000000 %
# epoch 734, minibatch 10/10, validation error 11.000000 %
# epoch 735, minibatch 10/10, validation error 11.000000 %
# epoch 736, minibatch 10/10, validation error 11.000000 %
# epoch 737, minibatch 10/10, validation error 11.000000 %
# epoch 738, minibatch 10/10, validation error 11.000000 %
# epoch 739, minibatch 10/10, validation error 11.000000 %
# epoch 740, minibatch 10/10, validation error 11.000000 %
# epoch 741, minibatch 10/10, validation error 11.000000 %
# epoch 742, minibatch 10/10, validation error 11.000000 %
# epoch 743, minibatch 10/10, validation error 11.000000 %
# epoch 744, minibatch 10/10, validation error 11.000000 %
# epoch 745, minibatch 10/10, validation error 11.000000 %
# epoch 746, minibatch 10/10, validation error 11.000000 %
# epoch 747, minibatch 10/10, validation error 11.000000 %
# epoch 748, minibatch 10/10, validation error 11.000000 %
# epoch 749, minibatch 10/10, validation error 11.000000 %
# epoch 750, minibatch 10/10, validation error 11.000000 %
# epoch 751, minibatch 10/10, validation error 11.000000 %
# epoch 752, minibatch 10/10, validation error 11.000000 %
# epoch 753, minibatch 10/10, validation error 11.000000 %
# epoch 754, minibatch 10/10, validation error 11.000000 %
# epoch 755, minibatch 10/10, validation error 11.000000 %
# epoch 756, minibatch 10/10, validation error 11.000000 %
# epoch 757, minibatch 10/10, validation error 11.000000 %
# epoch 758, minibatch 10/10, validation error 11.000000 %
# epoch 759, minibatch 10/10, validation error 11.000000 %
# epoch 760, minibatch 10/10, validation error 11.000000 %
# epoch 761, minibatch 10/10, validation error 11.000000 %
# epoch 762, minibatch 10/10, validation error 11.000000 %
# epoch 763, minibatch 10/10, validation error 11.000000 %
# epoch 764, minibatch 10/10, validation error 11.000000 %
# epoch 765, minibatch 10/10, validation error 11.000000 %
# epoch 766, minibatch 10/10, validation error 11.000000 %
# epoch 767, minibatch 10/10, validation error 11.000000 %
# epoch 768, minibatch 10/10, validation error 11.000000 %
# epoch 769, minibatch 10/10, validation error 11.000000 %
# epoch 770, minibatch 10/10, validation error 11.000000 %
# epoch 771, minibatch 10/10, validation error 11.000000 %
# epoch 772, minibatch 10/10, validation error 11.000000 %
# epoch 773, minibatch 10/10, validation error 11.000000 %
# epoch 774, minibatch 10/10, validation error 11.000000 %
# epoch 775, minibatch 10/10, validation error 11.000000 %
# epoch 776, minibatch 10/10, validation error 11.000000 %
# epoch 777, minibatch 10/10, validation error 11.000000 %
# epoch 778, minibatch 10/10, validation error 11.000000 %
# epoch 779, minibatch 10/10, validation error 11.000000 %
# epoch 780, minibatch 10/10, validation error 11.000000 %
# epoch 781, minibatch 10/10, validation error 11.000000 %
# epoch 782, minibatch 10/10, validation error 11.000000 %
# epoch 783, minibatch 10/10, validation error 11.000000 %
# epoch 784, minibatch 10/10, validation error 11.000000 %
# epoch 785, minibatch 10/10, validation error 11.000000 %
# epoch 786, minibatch 10/10, validation error 11.000000 %
# epoch 787, minibatch 10/10, validation error 11.000000 %
# epoch 788, minibatch 10/10, validation error 11.000000 %
# epoch 789, minibatch 10/10, validation error 11.000000 %
# epoch 790, minibatch 10/10, validation error 11.000000 %
# epoch 791, minibatch 10/10, validation error 11.000000 %
# epoch 792, minibatch 10/10, validation error 11.000000 %
# epoch 793, minibatch 10/10, validation error 11.000000 %
# epoch 794, minibatch 10/10, validation error 11.000000 %
# epoch 795, minibatch 10/10, validation error 11.000000 %
# epoch 796, minibatch 10/10, validation error 11.000000 %
# epoch 797, minibatch 10/10, validation error 11.000000 %
# epoch 798, minibatch 10/10, validation error 11.000000 %
# epoch 799, minibatch 10/10, validation error 11.000000 %
# epoch 800, minibatch 10/10, validation error 11.000000 %
# epoch 801, minibatch 10/10, validation error 11.000000 %
# epoch 802, minibatch 10/10, validation error 11.000000 %
# epoch 803, minibatch 10/10, validation error 11.000000 %
# epoch 804, minibatch 10/10, validation error 11.000000 %
# epoch 805, minibatch 10/10, validation error 11.000000 %
# epoch 806, minibatch 10/10, validation error 11.000000 %
# epoch 807, minibatch 10/10, validation error 11.000000 %
# epoch 808, minibatch 10/10, validation error 11.000000 %
# epoch 809, minibatch 10/10, validation error 11.000000 %
# epoch 810, minibatch 10/10, validation error 11.000000 %
# epoch 811, minibatch 10/10, validation error 11.000000 %
# epoch 812, minibatch 10/10, validation error 11.000000 %
# epoch 813, minibatch 10/10, validation error 11.000000 %
# epoch 814, minibatch 10/10, validation error 11.000000 %
# epoch 815, minibatch 10/10, validation error 11.000000 %
# epoch 816, minibatch 10/10, validation error 11.000000 %
# epoch 817, minibatch 10/10, validation error 11.000000 %
# epoch 818, minibatch 10/10, validation error 11.000000 %
# epoch 819, minibatch 10/10, validation error 11.000000 %
# epoch 820, minibatch 10/10, validation error 11.000000 %
# epoch 821, minibatch 10/10, validation error 11.000000 %
# epoch 822, minibatch 10/10, validation error 11.000000 %
# epoch 823, minibatch 10/10, validation error 11.000000 %
# epoch 824, minibatch 10/10, validation error 11.000000 %
# epoch 825, minibatch 10/10, validation error 11.000000 %
# epoch 826, minibatch 10/10, validation error 11.000000 %
# epoch 827, minibatch 10/10, validation error 11.000000 %
# epoch 828, minibatch 10/10, validation error 11.000000 %
# epoch 829, minibatch 10/10, validation error 11.000000 %
# Optimization complete. Best validation score of 11.000000 % obtained at iteration 4150, with test performance 12.000000 %
# The code ran for 1.40m
